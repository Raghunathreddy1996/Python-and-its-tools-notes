# %% [markdown]
# # PANDAS NOTES

# %% [raw]
# Pandas library used for
# = data manupulation and analysis
# = data cleaning

# %% [markdown]
# - pandas used for
#
# 1. **Data Loading** - Read data from various sources such as `csv`, `excel`, `sql databases`
# 2. **Data Inspection** - Quickly inspect and understand the data structure and content of your data using functions `head()`, `tail()`, `describe()`, `info()`
# 3. **Data Cleaning / Processing** - Identifying missing records in the data and fixing it, Handling duplicates, transforming data to the desired format
# 4. **Data Selection and Filtering** - Functions like `.loc()` and `.iloc()` will be slicing and filtering the data
# 5. **Data Manipulation** - Perform various data manipulation tasks such as sorting, grouping, aggregating, merging and pivoting using functions like `groupby()`, `agg()` , `merge()`, and `pivot_table()`
# 6. **Data Visualization** - Create visualization in Pandas

# %% [markdown]
# **SHIFT + TAB** --> For syntax / documentation
#
# **TAB** --> For showing all the possible options
#
# **SHIFT + ENTER** --> To run the current cell and go to next in Jupyter notebook,

# %% [markdown]
# https://www.w3resource.com/python-exercises/pandas/index.php

# %%
# !pip install pandas

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
len(dir(pd))
# Out:
# 144

# %%
import pandas as pd

# %% [markdown]
# Series is 1D data
#
# syntax = pd.Series([data,index,dtype])

# %%
empty = pd.Series()
print(empty)
# Out:
# Series([], dtype: float64)
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_39760\1378293409.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty = pd.Series()

# %%
type(empty)
# Out:
# pandas.core.series.Series

# %%
series = pd.Series([1,2,3,4])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#Giving index name

series = pd.Series([1,2,3,4],index=['a','b','c','d'],dtype=float)
print(series)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
a = [10,12,15,16,13]
ss = pd.Series(a, index = ['a','b','c','d','e'])
ss
# Out:
# a    10
# b    12
# c    15
# d    16
# e    13
# dtype: int64

# %%
#converting array into series
import numpy as np
arr = np.array(['R','E','D','D','y'])
ar = pd.Series(arr)
print(ar)
# Out:
# 0    R
# 1    E
# 2    D
# 3    D
# 4    y
# dtype: object

# %%
print(arr)
type(arr)
# Out:
# ['R' 'E' 'D' 'D' 'y']
# numpy.ndarray

# %%
arr = np.array(['R','E','D','D','y'])
index = [1,2,3,4,5]
ar = pd.Series(arr,index)
print(ar)
# Out:
# 1    R
# 2    E
# 3    D
# 4    D
# 5    y
# dtype: object

# %%
ar.index
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')

# %%
ar.values
# Out:
# array(['R', 'E', 'D', 'D', 'y'], dtype=object)

# %%
#convrting dictionary to series

dic = {'a':100,"b":200,'c':300,'d':400}
d = pd.Series(dic)
print(d)
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
#  DataFrame is 2D data , lebelled data structure
#
# syntax : pd.DataFrame([data,index,columns,dtype])

# %%
#creating empty DF
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
series = pd.Series([1,2,3,4])
d1 = pd.DataFrame(series)
d1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
d1 = pd.DataFrame(series,columns = ['num'],dtype = int)
d1
# Out:
#    num
# 0    1
# 1    2
# 2    3
# 3    4

# %%
ls = [10,20,30,40]
df = pd.DataFrame(ls, index = ['a','b','c','d'], columns = ['ID'])
df
# Out:
#    ID
# a  10
# b  20
# c  30
# d  40

# %%
df.columns = ['p_ID']
df
# Out:
#    p_ID
# a    10
# b    20
# c    30
# d    40

# %%
df.rename(columns = {"ID":"pp_ID"})
# Out:
#    pp_ID
# a     10
# b     20
# c     30
# d     40

# %%
df.index = [1,2,3,4]
df
# Out:
#    p_ID
# 1    10
# 2    20
# 3    30
# 4    40

# %%
#adding new column
df['name'] = ['a','b','h','y']
df
# Out:
#    p_ID name
# 1    10    a
# 2    20    b
# 3    30    h
# 4    40    y

# %%
#2D array to Df

arr = [['aa',100],['bb',200],['cc',300]]
d2 = pd.DataFrame(arr)
d2

# %%
arr = [['aa',100],['bb',200],['cc',300]]

d2 = pd.DataFrame(arr,index = ['x','y','z'], columns =['name','ID'])
d2
# Out:
#   name   ID
# x   aa  100
# y   bb  200
# z   cc  300

# %%
#Dict to Df

dict1 = {'Name':['raj','wad','ved','sed'],'ID':[101,102,103,104]}
print(type(dict1))
df = pd.DataFrame(dict1)
df
# Out:
# <class 'dict'>
#   Name   ID
# 0  raj  101
# 1  wad  102
# 2  ved  103
# 3  sed  104

# %%
python_score = {'Akash':19, 'Monica': 18, 'Gaurav':5, 'Shivansh':17, 'Sangya':20, 'Ajay':9}

# %%
python_score
# Out:
# {'Akash': 19,
#  'Monica': 18,
#  'Gaurav': 5,
#  'Shivansh': 17,
#  'Sangya': 20,
#  'Ajay': 9}

# %%
python_score.keys()
# Out:
# dict_keys(['Akash', 'Monica', 'Gaurav', 'Shivansh', 'Sangya', 'Ajay'])

# %%
pds_python_score = pd.Series(python_score)

# %%
pds_python_score
# Out:
# Akash       19
# Monica      18
# Gaurav       5
# Shivansh    17
# Sangya      20
# Ajay         9
# dtype: int64

# %%
pds_python_score_1 = pd.Series(python_score, ['Akash', 'Monica', 'Neha', 'Shivansh', 'Sneha', 'Ajay'])

# %%
pds_python_score_1
# Out:
# Akash       19.0
# Monica      18.0
# Neha         NaN
# Shivansh    17.0
# Sneha        NaN
# Ajay         9.0
# dtype: float64

# %%
filt = pds_python_score > 10 #criteria for filtering
filt
# Out:
# Akash        True
# Monica       True
# Gaurav      False
# Shivansh     True
# Sangya       True
# Ajay        False
# dtype: bool

# %%
pds_python_score[filt] #masking concept to filtering
# Out:
# Akash       19
# Monica      18
# Shivansh    17
# Sangya      20
# dtype: int64

# %% [markdown]
# ### Basic Descriptive Statistics

# %%
print('Avg. Python Score:', pds_python_score.mean())
print('Min. Python Score:', pds_python_score.min())
print('Max. Python Score:', pds_python_score.max())
print('Median Python Score:', pds_python_score.median())
print('Variance of Python Score:', pds_python_score.var())
print('Std. Deviation Score:', pds_python_score.std())
# Out:
# Avg. Python Score: 14.666666666666666
# Min. Python Score: 5
# Max. Python Score: 20
# Median Python Score: 17.5
# Variance of Python Score: 37.86666666666667
# Std. Deviation Score: 6.153589738247641

# %% [markdown]
# ### Series Object Attributes

# %% [markdown]
#     - Series.index: Defines the index of the Series.
#     - Series.shape: It returns a tuple of shape of the data.
#     - Series.dtype: It returns the data type of the data.
#     - Series.size: It returns the size of the data.
#     - Series.empty: It returns True if Series object is empty, otherwise returns false.
#     - Series.hasnans:It returns True if there are any NaN values, otherwise returns false.
#     - Series.nbytes: It returns the number of bytes in the data.
#     - Series.ndim: It returns the number of dimensions in the data.

# %%
pds_python_score.index
# Out:
# Index(['Akash', 'Monica', 'Gaurav', 'Shivansh', 'Sangya', 'Ajay'], dtype='object')

# %%
pds_python_score.shape
# Out:
# (6,)

# %%
pds_python_score.dtype
# Out:
# dtype('int64')

# %%
pds_python_score.size
# Out:
# 6

# %%
pds_python_score.nbytes
# Out:
# 48

# %%
pds_python_score.empty
# Out:
# False

# %%
pds_python_score.hasnans #checks for missing data if you have any --NaNs
# Out:
# False

# %% [markdown]
# ### Checking Emptiness and Presence of NaNs

# %%
zz = pd.Series([1,5,3,4,'red',np.NaN,True])
zz
# Out:
# 0       1
# 1       5
# 2       3
# 3       4
# 4     red
# 5     NaN
# 6    True
# dtype: object

# %%
zz.hasnans
# Out:
# True

# %% [markdown]
# ### `isna()` & `isnull()` - to check missing values

# %%
zz.isna()    #isna() - returns the boolean flag for missing data
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
zz.isnull() #isnull() - returns the boolean flag for missing data
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
zz.empty #although it has some missing values but still have some values its not completely empty
# Out:
# False

# %%
empty_series = pd.Series() #empty series => declares it in the memory but no values initialised for it
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_29012\4105752567.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_series = pd.Series() #empty series => declares it in the memory but no values initialised for it

# %%
empty_series.empty
# Out:
# True

# %%
new_ser_nan = pd.Series([np.NaN, np.NaN, np.NaN])

# %%
new_ser_nan
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# dtype: float64

# %%
new_ser_nan.empty
# Out:
# False

# %%
pds_python_score
# Out:
# Akash       19
# Monica      18
# Gaurav       5
# Shivansh    17
# Sangya      20
# Ajay         9
# dtype: int64

# %%
pds_python_score['Gaurav']=12

# %%
pds_python_score
# Out:
# Akash       19
# Monica      18
# Gaurav      12
# Shivansh    17
# Sangya      20
# Ajay         9
# dtype: int64

# %%
'Ajay' in pds_python_score
# Out:
# True

# %%
'Rahul' in pds_python_score
# Out:
# False

# %%
aaa = [1,3,2,4]
aaa
# Out:
# [1, 3, 2, 4]

# %%
aaa*2           #list concatenation but not a vectorized operation
# Out:
# [1, 3, 2, 4, 1, 3, 2, 4]

# %%
pds_python_score*2 #it does support vectorized operation
# Out:
# Akash       38
# Monica      36
# Gaurav      24
# Shivansh    34
# Sangya      40
# Ajay        18
# dtype: int64

# %%
pds_python_score/2 #it does support vectorized operation
# Out:
# Akash        9.5
# Monica       9.0
# Gaurav       6.0
# Shivansh     8.5
# Sangya      10.0
# Ajay         4.5
# dtype: float64

# %%
pds_python_score+100 #it does support vectorized operation
# Out:
# Akash       119
# Monica      118
# Gaurav      112
# Shivansh    117
# Sangya      120
# Ajay        109
# dtype: int64

# %%
pds_python_score.sort_index() #sorting the index
# Out:
# Ajay         9
# Akash       19
# Gaurav      12
# Monica      18
# Sangya      20
# Shivansh    17
# dtype: int64

# %%
pds_python_score.sort_values() #sorting the values
# Out:
# Ajay         9
# Gaurav      12
# Shivansh    17
# Monica      18
# Akash       19
# Sangya      20
# dtype: int64

# %%
T2 = pd.DataFrame([['a','b','c','d'],
               [5,6,7,8],
                 ['q1','q2','q3','q4']])
T2
# Out:
#     0   1   2   3
# 0   a   b   c   d
# 1   5   6   7   8
# 2  q1  q2  q3  q4

# %% [markdown]
# # MERGE  FUNCTION

# %%
T1 = pd.DataFrame({'Alpha':['a','b','c','d'],
                 "num":[1,2,3,4],
                 "alphanum":['a1','b2','vc3','d4']})
T1
# Out:
#   Alpha  num alphanum
# 0     a    1       a1
# 1     b    2       b2
# 2     c    5      vc3
# 3     d    6       d4

# %%
T2 = pd.DataFrame({'Alpha':['a','b','c','d'],
                 "num":[5,6,7,8],
                 "alphanum":['q1','q2','q3','q4']})
T2
# Out:
#   Alpha  num alphanum
# 0     a    5       q1
# 1     b    6       q2
# 2     c    7       q3
# 3     d    8       q4

# %%
merge1 = pd.merge(T1,T2,on = 'Alpha')
merge1
# Out:
#   Alpha  num_x alphanum_x  num_y alphanum_y
# 0     a      1         a1      5         q1
# 1     b      2         b2      6         q2
# 2     c      5        vc3      7         q3
# 3     d      6         d4      8         q4

# %% [markdown]
# - inner: the default join type in Pandas merge() function and it produces records that have matching values in both DataFrames
# - left: produces all records from the left DataFrame and the matched records from the right DataFrame
# - right: produces all records from the right DataFrame and the matched records from the left DataFrame
# - outer: produces all records when there is a match in either left or right DataFrame

# %%
df_student = pd.DataFrame({
    'stu_id': [1,2,3,4, 99],
    'name':['Akash', 'Kavitha', 'Varun','Nitish', 'Sachin']
})

# %%
df_student
# Out:
#    stu_id     name
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish
# 4      99   Sachin

# %%
df_student_info = pd.DataFrame({
    'stu_id': [1,2,3,4,5,6,7],
    'age':[34,20,21,18,25,20,18],
    'sex': ['M','F','M','M','F','M','M']
})

# %%
df_student_info
# Out:
#    stu_id  age sex
# 0       1   34   M
# 1       2   20   F
# 2       3   21   M
# 3       4   18   M
# 4       5   25   F
# 5       6   20   M
# 6       7   18   M

# %% [markdown]
# ### inner join

# %%
pd.merge(df_student, df_student_info, how='inner', on='stu_id')
# Out:
#    stu_id     name  age sex
# 0       1    Akash   34   M
# 1       2  Kavitha   20   F
# 2       3    Varun   21   M
# 3       4   Nitish   18   M

# %%
pd.merge(df_student, df_student_info)  # inner is default
# Out:
#    stu_id     name  age sex
# 0       1    Akash   34   M
# 1       2  Kavitha   20   F
# 2       3    Varun   21   M
# 3       4   Nitish   18   M

# %%
df_student.merge(df_student_info)
# Out:
#    stu_id     name  age sex
# 0       1    Akash   34   M
# 1       2  Kavitha   20   F
# 2       3    Varun   21   M
# 3       4   Nitish   18   M

# %%
df_student = pd.DataFrame({
    'student_id': [1,2,3,4, 99],
    'age':[34,20,21,18,45],
    'name':['Akash', 'Kavitha', 'Varun','Nitish', 'Sachin']
})

# %%
df_student
# Out:
#    student_id  age     name
# 0           1   34    Akash
# 1           2   20  Kavitha
# 2           3   21    Varun
# 3           4   18   Nitish
# 4          99   45   Sachin

# %%
df_student_info = pd.DataFrame({
    'stu_id': [1,2,3,4,5,6,7],
    'age':[64,20,22,38,25,20,18],
    'sex': ['M','F','M','M','F','M','M']
})

# %%
df_student_info
# Out:
#    stu_id  age sex
# 0       1   64   M
# 1       2   20   F
# 2       3   22   M
# 3       4   38   M
# 4       5   25   F
# 5       6   20   M
# 6       7   18   M

# %%
pd.merge(df_student, df_student_info, how='inner', on='stu_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 pd.merge(df_student, df_student_info, how='inner', on='stu_id')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
pd.merge(df_student, df_student_info, how = 'inner', left_on = 'student_id', right_on = 'stu_id')
# Out:
#    student_id  age_x     name  stu_id  age_y sex
# 0           1     34    Akash       1     64   M
# 1           2     20  Kavitha       2     20   F
# 2           3     21    Varun       3     22   M
# 3           4     18   Nitish       4     38   M

# %% [markdown]
# **on** can only be used when the key is a having same column name else go with `left_on` and `right_on`

# %%
apc = pd.merge(df_student, df_student_info, how='inner', left_on='student_id', right_on='stu_id')

# %%
apc
# Out:
#    student_id  age_x     name  stu_id  age_y sex
# 0           1     34    Akash       1     64   M
# 1           2     20  Kavitha       2     20   F
# 2           3     21    Varun       3     22   M
# 3           4     18   Nitish       4     38   M

# %%
apc['age_x'] = apc['age_y']

# %%
apc
# Out:
#    student_id  age_x     name  stu_id  age_y sex
# 0           1     64    Akash       1     64   M
# 1           2     20  Kavitha       2     20   F
# 2           3     22    Varun       3     22   M
# 3           4     38   Nitish       4     38   M

# %% [markdown]
# ### left join (merge)

# %%
df_student
# Out:
#    student_id  age     name
# 0           1   34    Akash
# 1           2   20  Kavitha
# 2           3   21    Varun
# 3           4   18   Nitish
# 4          99   45   Sachin

# %%
df_student_info = pd.DataFrame({
    'stu_id': [1,2,3,4,5,6,7],
    'age':[34,20,21,18,25,20,18],
    'sex': ['M','F','M','M','F','M','M']
})
df_student_info
# Out:
#    stu_id  age sex
# 0       1   34   M
# 1       2   20   F
# 2       3   21   M
# 3       4   18   M
# 4       5   25   F
# 5       6   20   M
# 6       7   18   M

# %%
leftm = pd.merge(df_student, df_student_info, how = 'left', left_on = 'student_id', right_on = 'stu_id')

# %%
leftm
# Out:
#    student_id  age_x     name  stu_id  age_y  sex
# 0           1     34    Akash     1.0   34.0    M
# 1           2     20  Kavitha     2.0   20.0    F
# 2           3     21    Varun     3.0   21.0    M
# 3           4     18   Nitish     4.0   18.0    M
# 4          99     45   Sachin     NaN    NaN  NaN

# %% [markdown]
# ### right join (merge)

# %%
df_stu_merg_right = pd.merge(df_student, df_student_info, how='right', left_on='student_id', right_on='stu_id')

# %%
df_stu_merg_right
# Out:
#    student_id  age_x     name  stu_id  age_y sex
# 0         1.0   34.0    Akash       1     34   M
# 1         2.0   20.0  Kavitha       2     20   F
# 2         3.0   21.0    Varun       3     21   M
# 3         4.0   18.0   Nitish       4     18   M
# 4         NaN    NaN      NaN       5     25   F
# 5         NaN    NaN      NaN       6     20   M
# 6         NaN    NaN      NaN       7     18   M

# %%
pd.merge(df_student_info, df_student, how='left', left_on='stu_id', right_on='student_id')
# Out:
#    stu_id  age_x sex  student_id  age_y     name
# 0       1     34   M         1.0   34.0    Akash
# 1       2     20   F         2.0   20.0  Kavitha
# 2       3     21   M         3.0   21.0    Varun
# 3       4     18   M         4.0   18.0   Nitish
# 4       5     25   F         NaN    NaN      NaN
# 5       6     20   M         NaN    NaN      NaN
# 6       7     18   M         NaN    NaN      NaN

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'str' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool' = True, indicator: 'bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     .. warning::
#
# ...

# %% [markdown]
# ### Outer join => all to all combinations

# %%
pd.merge(df_student, df_student_info, how='outer', left_on='student_id', right_on='stu_id')
# Out:
#    student_id  age_x     name  stu_id  age_y  sex
# 0         1.0   34.0    Akash     1.0   34.0    M
# 1         2.0   20.0  Kavitha     2.0   20.0    F
# 2         3.0   21.0    Varun     3.0   21.0    M
# 3         4.0   18.0   Nitish     4.0   18.0    M
# 4        99.0   45.0   Sachin     NaN    NaN  NaN
# 5         NaN    NaN      NaN     5.0   25.0    F
# 6         NaN    NaN      NaN     6.0   20.0    M
# 7         NaN    NaN      NaN     7.0   18.0    M

# %% [markdown]
# # JOIN

# %% [markdown]
# - join() is used to combine two dataframes on the index but no columns
# - merge() is primarily used to specify the columns on which you wanted to join on

# %%
df1 = pd.DataFrame({'key':[55,66,77,88],"nam":['rr','ww','yy','xx']})
df2 = pd.DataFrame({'key':[55,77],'num':['rr','yy']})

df_join = df1.join(df2, lsuffix = 'df1', rsuffix ='df2')
df_join
# Out:
#    keydf1 nam  keydf2  num
# 0      55  rr    55.0   rr
# 1      66  ww    77.0   yy
# 2      77  yy     NaN  NaN
# 3      88  xx     NaN  NaN

# %% [markdown]
# **NaN** means Not a Number => data is missing / null values / empty cells

# %%
df_student.join(df_student_info, how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 df_student.join(df_student_info, how='inner')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
#    9986         validate=validate,
#    9987     )
#
# ...

# %%
df_student.join(df_student_info, how='inner', lsuffix='_left', rsuffix='_right')
# Out:
#    student_id  age_left     name  stu_id  age_right sex
# 0           1        34    Akash       1         34   M
# 1           2        20  Kavitha       2         20   F
# 2           3        21    Varun       3         21   M
# 3           4        18   Nitish       4         18   M
# 4          99        45   Sachin       5         25   F

# %% [markdown]
# - concat() & append() are two import functions which are used to combine data frames in Python
# - concat() is used to combine dataframes along a particular axis (by row/column)
# - append() is used to combine dataframes by rows (more like stacking)

# %% [markdown]
# # CONCATENATION

# %%
df1 = pd.DataFrame({'name':['jane','john','jacob'],
                   'age':[15,25,25]},index=[2,3,4])
df2 = pd.DataFrame({'name':['june','jilia','jacorb'],
                'age':[21,26,35]},index=[6,7,8])
df3 = pd.DataFrame({'name':['jan1e','jo1hn','jac1ob'],
                   'age':[15,25,25]},index=[10,11,12])

df = pd.concat([df1,df2,df3]) # default axis = 0
df
# Out:
#       name  age
# 2     jane   15
# 3     john   25
# 4    jacob   25
# 6     june   21
# 7    jilia   26
# 8   jacorb   35
# 10   jan1e   15
# 11   jo1hn   25
# 12  jac1ob   25

# %%
df = pd.concat([df1,df2,df3], axis=1)
df
# Out:
#      name   age    name   age    name   age
# 2    jane  15.0     NaN   NaN     NaN   NaN
# 3    john  25.0     NaN   NaN     NaN   NaN
# 4   jacob  25.0     NaN   NaN     NaN   NaN
# 6     NaN   NaN    june  21.0     NaN   NaN
# 7     NaN   NaN   jilia  26.0     NaN   NaN
# 8     NaN   NaN  jacorb  35.0     NaN   NaN
# 10    NaN   NaN     NaN   NaN   jan1e  15.0
# 11    NaN   NaN     NaN   NaN   jo1hn  25.0
# 12    NaN   NaN     NaN   NaN  jac1ob  25.0

# %%
## Data frames 

D = {"Name":['n1','n2','n3','n4'], "Age":[23,34,45,56]}

df1 = pd.DataFrame(D, index = ['q','w','e','r'])
df2 = pd.DataFrame(D, index = ['q','w','e','r'])
print(df1)
print(df2)
# Out:
#   Name  Age
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56
#   Name  Age
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56

# %%
pd.concat([df1,df2], axis = 0) #row wise
# Out:
#   Name  Age
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56

# %%
pd.concat([df1,df2], axis = 1) # column wise
# Out:
#   Name  Age Name  Age
# q   n1   23   n1   23
# w   n2   34   n2   34
# e   n3   45   n3   45
# r   n4   56   n4   56

# %%
## Data frames 

D = {"Name":['n1','n2','n3','n4'], "Age":[23,34,45,56]}

df1 = pd.DataFrame(D, index = ['a','b','e','r'])
df2 = pd.DataFrame(D, index = ['q','w','e','r'])
print(df1)
print(df2)
# Out:
#   Name  Age
# a   n1   23
# b   n2   34
# e   n3   45
# r   n4   56
#   Name  Age
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56

# %%
pd.concat([df1,df2], axis = 0)
# Out:
#   Name  Age
# a   n1   23
# b   n2   34
# e   n3   45
# r   n4   56
# q   n1   23
# w   n2   34
# e   n3   45
# r   n4   56

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#   Name   Age Name   Age
# a   n1  23.0  NaN   NaN
# b   n2  34.0  NaN   NaN
# e   n3  45.0   n3  45.0
# r   n4  56.0   n4  56.0
# q  NaN   NaN   n1  23.0
# w  NaN   NaN   n2  34.0

# %%
df11= pd.DataFrame({
    'stu_id':[10,11,12],
    'name':['Ram','Monica', 'Abhay']
    
})

# %%
df12 = pd.DataFrame({
    'stu_id': [1,2,3,4, 99],
    'name':['Akash', 'Kavitha', 'Varun','Nitish', 'Sachin']
})

# %%
pd.concat([df11, df12])  #by default axis - 0
# Out:
#    stu_id     name
# 0      10      Ram
# 1      11   Monica
# 2      12    Abhay
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish
# 4      99   Sachin

# %%
pd.concat([df11, df12], ignore_index = True)
# Out:
#    stu_id     name
# 0      10      Ram
# 1      11   Monica
# 2      12    Abhay
# 3       1    Akash
# 4       2  Kavitha
# 5       3    Varun
# 6       4   Nitish
# 7      99   Sachin

# %%
pd.concat([df11,df12],axis =1 )
# Out:
#    stu_id    name  stu_id     name
# 0    10.0     Ram       1    Akash
# 1    11.0  Monica       2  Kavitha
# 2    12.0   Abhay       3    Varun
# 3     NaN     NaN       4   Nitish
# 4     NaN     NaN      99   Sachin

# %% [markdown]
# ## append()

# %%
df12.append(df12, ignore_index = True)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_29012\3822792963.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12.append(df12, ignore_index = True)
#    stu_id     name
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish
# 4      99   Sachin
# 5       1    Akash
# 6       2  Kavitha
# 7       3    Varun
# 8       4   Nitish
# 9      99   Sachin

# %%
df12.append(df12)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_29012\3515797746.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12.append(df12)
#    stu_id     name
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish
# 4      99   Sachin
# 0       1    Akash
# 1       2  Kavitha
# 2       3    Varun
# 3       4   Nitish
# 4      99   Sachin

# %% [markdown]
# ### Assigning Columns Names to Data without headers

# %%
technologies = [['Python', 50, 'APC'],
               ['Pandas', 12, 'APC'],
               ['Google Cloud', 30,'BBC']]
type(technologies)
# Out:
# list

# %%
technologies
# Out:
# [['Python', 50, 'APC'], ['Pandas', 12, 'APC'], ['Google Cloud', 30, 'BBC']]

# %%
col_names = ['Course', 'Hours Required', 'Instructor']
col_names
# Out:
# ['Course', 'Hours Required', 'Instructor']

# %%
df = pd.DataFrame(technologies, columns = col_names)
df
# Out:
#          Course  Hours Required Instructor
# 0        Python              50        APC
# 1        Pandas              12        APC
# 2  Google Cloud              30        BBC

# %% [markdown]
# ### Change column names in existing DataFrame

# %% [markdown]
# #### Method #1 Using `rename` function

# %%
df.rename(columns =  {'Course':'Module', 'Instructor':'Trainer'})
# Out:
#          Module  Hours Required Trainer
# 0        Python              50     APC
# 1        Pandas              12     APC
# 2  Google Cloud              30     BBC

# %%
df
# Out:
#          Course  Hours Required Instructor
# 0        Python              50        APC
# 1        Pandas              12        APC
# 2  Google Cloud              30        BBC

# %%
df.rename(columns =  {'Course':'Module', 'Instructor':'Trainer'}, inplace =True)

# %%
df  # inplace = True, used to make change appear in original table too
# Out:
#          Module  Hours Required Trainer
# 0        Python              50     APC
# 1        Pandas              12     APC
# 2  Google Cloud              30     BBC

# %% [markdown]
# #### Method #2 Using `columns` function

# %%
df.columns
# Out:
# Index(['Module', 'Hours Required', 'Trainer'], dtype='object')

# %%
df.columns = ['Module', ' Time Required (in hrs)', 'Trainer1']

# %%
df
# Out:
#          Module   Time Required (in hrs) Trainer1
# 0        Python                       50      APC
# 1        Pandas                       12      APC
# 2  Google Cloud                       30      BBC

# %% [markdown]
# ## Analysing of Dataset

# %% [markdown]
# # Exploratory Data Analysis - EDA¶

# %%
## Read external dataset 

import pandas as pd 

df = pd.read_csv("F:/Course pdf/3.Pandas/class/mtcars2.csv")
# pd.read_csv('mtcars.csv')
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %% [raw]
# #while entering file name make \ backslash to / forword   slash the enter your file name
# #csv means comma separated values

# %% [raw]
# >>>to import data
#  use - read_csv for csv dataset
#      - read_excel for Excel dataset
#      - read_sql for sql dataset

# %%
aa = pd.read_excel("F:/course pdf/9.power BI/class/case study/Data Files/APEX Profits.xlsx")
aa.head()
# Out:
#    Unnamed: 0      Unnamed: 1       Unnamed: 2
# 0  APEX Sales             NaN              NaN
# 1         NaN             NaN              NaN
# 2     Country  Facial Quarter  Profit in USD M
# 3   Australia   FY2010-11, Q1             3500
# 4         NaN   FY2011-12, Q1             4000

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (32, 13)

# %%
df.size
# Out:
# 416

# %%
df.head(2) # default 5 row
# Out:
#    S.No     Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1      Mazda RX4  21.0    6  160.0  110   3.9  2.620  16.46   0   1
# 1     2  Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1
#
#    gear  carb
# 0     4     4
# 1     4     4

# %%
df.tail(3)  # default 5 row
# Out:
#     S.No     Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 29    30   Ferrari Dino  19.7    6  145.0  175  3.62  2.77  15.5   0   1
# 30    31  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1
# 31    32     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1
#
#     gear  carb
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.head(8).T        #transpose
# Out:
#                     0              1           2               3  \
# S.No                1              2           3               4
# Unnamed: 1  Mazda RX4  Mazda RX4 Wag  Datsun 710  Hornet 4 Drive
# mpg              21.0           21.0        22.8            21.4
# cyl                 6              6           4               6
# disp            160.0          160.0       108.0           258.0
# hp                110            110          93             110
# drat              3.9            3.9        3.85            3.08
# wt               2.62          2.875        2.32           3.215
# qsec            16.46          17.02       18.61           19.44
# vs                  0              0           1               1
# am                  1              1           1               0
# gear                4              4           4               3
# carb                4              4           1               1
#
# ...

# %% [markdown]
# sample(): it shows the random rows of your data

# %%
df.sample(6)
# Out:
#     S.No     Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 2      3     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 11    12     Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 30    31  Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 20    21  Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 17    18       Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   1   1
# 7      8      Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
#
#     gear  carb
# 2      4     1
# 11     3     3
# 30     5     8
# 20     3     1
# 17     4     1
# 7      4     2

# %%
df.sample(3).T
# Out:
#                      18             26            27
# S.No                 19             27            28
# Unnamed: 1  Honda Civic  Porsche 914-2  Lotus Europa
# mpg                30.4           26.0          30.4
# cyl                   4              4             4
# disp               75.7          120.3          95.1
# hp                   52             91           113
# drat               4.93           4.43          3.77
# wt                1.615           2.14         1.513
# qsec              18.52           16.7          16.9
# vs                    1              0             1
# am                    1              1             1
# gear                  4              5             5
# carb                  2              2             2

# %%
#df.info(): this is your first command after you load your data
# used to get the info avout data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
df.dtypes
# Out:
# S.No            int64
# Unnamed: 1     object
# mpg           float64
# cyl             int64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      7
# float64    5
# object     1
# dtype: int64

# %%
df.shape
# Out:
# (32, 13)

# %%
df1 = df.copy()

# %%
df1.rename(columns = {'mpg':'MPG', 'cyl':'CYL'}, inplace =True)
df1.head(1)
# Out:
#    S.No Unnamed: 1   MPG  CYL   disp   hp    wt   qsec  vs  am  gear  carb
# 0     1  Mazda RX4  21.0    6  160.0  110  2.62  16.46   0   1     4     4

# %%
df1.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'MPG', 'CYL', 'disp', 'hp', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df1.columns = ['No', 'model', 'MPG', 'CYL', 'disp', 'hp', 'wt', 'qsec', 'vs',
       'am', 'gear', 'carb']

# %%
df1.head(1)
# Out:
#    No      model   MPG  CYL   disp   hp    wt   qsec  vs  am  gear  carb
# 0   1  Mazda RX4  21.0    6  160.0  110  2.62  16.46   0   1     4     4

# %% [markdown]
#   ### Dupliacate

# %%
df.duplicated()  # to find duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
# Display duplicated entries
df.duplicated().sum()
# Out:
# 0

# %%
duplicate_value = df.duplicated(keep='first')

# %%
df.loc[duplicate_value, :]
# Out:
# Empty DataFrame
# Columns: [S.No, Unnamed: 1, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb]
# Index: []

# %%
# dropping ALL duplicate values
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
df.isna()
# Out:
#      S.No  Unnamed: 1    mpg    cyl   disp     hp   drat     wt   qsec     vs  \
# 0   False       False  False  False  False  False  False  False  False  False
# 1   False       False  False  False  False  False  False  False  False  False
# 2   False       False  False  False  False  False  False  False  False  False
# 3   False       False  False  False  False  False  False  False  False  False
# 4   False       False  False  False  False  False  False  False  False  False
# 5   False       False  False  False  False  False  False  False   True  False
# 6   False       False  False  False  False  False  False  False  False  False
# 7   False       False  False  False  False  False  False  False  False  False
# 8   False       False  False  False  False  False  False  False  False  False
# 9   False       False  False  False  False  False  False  False  False  False
# 10  False       False  False  False  False  False  False  False  False  False
# ...

# %%
df.isna().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          3
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# qsec          3
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          3
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.isnull()     #returns a boolean flag for null - True and non-null - False
# Out:
#      S.No  Unnamed: 1    mpg    cyl   disp     hp   drat     wt   qsec     vs  \
# 0   False       False  False  False  False  False  False  False  False  False
# 1   False       False  False  False  False  False  False  False  False  False
# 2   False       False  False  False  False  False  False  False  False  False
# 3   False       False  False  False  False  False  False  False  False  False
# 4   False       False  False  False  False  False  False  False  False  False
# 5   False       False  False  False  False  False  False  False   True  False
# 6   False       False  False  False  False  False  False  False  False  False
# 7   False       False  False  False  False  False  False  False  False  False
# 8   False       False  False  False  False  False  False  False  False  False
# 9   False       False  False  False  False  False  False  False  False  False
# 10  False       False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# There are general options in dealing with nulls:
#
#     1. Columns / Rows are of least importance: Get rid of rows or columns with nulls
#
#     2. Imputation: Replace nulls with non-null values (Mean, Median, Mode Imputation)
#
#     3. ML based Imputation: Will be taught later
#
#     ---- many more

# %%
df.dropna(inplace = True) # operation will remove the rows with even a single null in any of the columns

# %%
#removeing null from perticular column
df.dropna(subset =['qsec'], inplace = True)

# %% [markdown]
# `inplace = True` => it makes the changes in the original dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int32
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float32
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float32(1), float64(4), int32(1), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
#show the list of all column
df.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %% [markdown]
# **change datatype**

# %%
df['S.No'] = df["S.No"].astype('int32')

# %%
df.drat = df.drat.astype('float32')

# %%
import pandas as pd 

df = pd.read_csv("F:/Course pdf/3.Pandas/class/mtcars2.csv")
# pd.read_csv('mtcars.csv')
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.count()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
# Extracting one column needs a pair of square brackets
df["mpg"].head(3)
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# Name: mpg, dtype: float64

# %%
# Extracting more than one column ==> need two pair of square brackets
df[[ 'mpg', 'cyl', 'disp', 'hp']].head()
# Out:
#     mpg  cyl   disp   hp
# 0  21.0    6  160.0  110
# 1  21.0    6  160.0  110
# 2  22.8    4  108.0   93
# 3  21.4    6  258.0  110
# 4  18.7    8  360.0  175

# %%
df.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %%
df[['carb','disp','vs','qsec']].head()  #selection + arrangement(we can interchange col order)
# Out:
#    carb   disp  vs   qsec
# 0     4  160.0   0  16.46
# 1     4  160.0   0  17.02
# 2     1  108.0   1  18.61
# 3     1  258.0   1  19.44
# 4     2  360.0   0  17.02

# %%
df[2:7]
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5     6            Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6     7         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
#
#    gear  carb
# 2     4     1
# 3     3     1
# 4     3     2
# 5     3     1
# 6     3     4

# %%
df[-2:]
# Out:
#     S.No     Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 30    31  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1
# 31    32     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1
#
#     gear  carb
# 30     5     8
# 31     4     2

# %%
df.gear.unique()   #unqiue / distinct list of any column
# Out:
# array([4, 3, 5], dtype=int64)

# %%
df.gear.nunique()    #unqiue / distinct count of any column
# Out:
# 3

# %%
df['vs'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['gear'].value_counts() 
# Returns a frequency of all categories showing the highest frequency on the top
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %% [markdown]
# If we want to show with the percentage of occurrence rather number than we use
# normalize=True argument in value_counts() function

# %%
df.gear.value_counts(normalize = True)
# Out:
# 3    0.46875
# 4    0.37500
# 5    0.15625
# Name: gear, dtype: float64

# %%
df.drat.value_counts().sort_values(ascending=False)
# Out:
# 3.92    3
# 3.07    3
# 3.90    2
# 4.22    2
# 3.08    2
# 3.15    2
# 2.76    2
# 4.08    2
# 4.93    1
# 3.21    1
# 3.69    1
# 2.93    1
# 3.00    1
# 3.85    1
# 4.43    1
# 3.23    1
# 3.70    1
# 3.73    1
# 3.77    1
# 3.62    1
# 3.54    1
# 4.11    1
# Name: drat, dtype: int64

# %%
aa = df.mpg.describe()

# %%
aa
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
aa.count
# Out:
# <bound method Series.count of count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64>

# %%
aa['count']
# Out:
# 32.0

# %%
aa['max']
# Out:
# 33.9

# %%
df['Unnamed: 1'].mode().iloc[0]
# Out:
# 'AMC Javelin'

# %%
df.mpg.count()
# Out:
# 32

# %%
df['mpg'].count()
# Out:
# 32

# %%
df[['mpg','hp']].count()
# Out:
# mpg    32
# hp     32
# dtype: int64

# %%
df.count().sum()
# Out:
# 413

# %%
df.min()
# Out:
# S.No                    1
# Unnamed: 1    AMC Javelin
# mpg                  10.4
# cyl                     4
# disp                 71.1
# hp                     52
# drat                 2.76
# wt                  1.513
# qsec                 14.5
# vs                      0
# am                      0
# gear                    3
# carb                    1
# dtype: object

# %%
df['mpg'].min()
# Out:
# 10.4

# %%
df.max()
# Out:
# S.No                  32
# Unnamed: 1    Volvo 142E
# mpg                 33.9
# cyl                    8
# disp               472.0
# hp                   335
# drat                4.93
# wt                 5.424
# qsec                22.9
# vs                     1
# am                     1
# gear                   5
# carb                   8
# dtype: object

# %%
df['mpg'].max()
# Out:
# 33.9

# %%
df.mean()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_39760\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# S.No     16.500000
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.674828
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df['mpg'].mean()
# Out:
# 20.090625000000003

# %%
df.mpg.mean()
# Out:
# 20.090625000000003

# %%
df.median()
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_39760\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# S.No     16.500
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.420
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
## Access the columns of a dataframe
df['mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df.mpg
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.mpg.sum()
# Out:
# 642.9000000000001

# %%
df.mpg = df.mpg.astype(int)  # converting data type
df.mpg
# Out:
# 0     21
# 1     21
# 2     22
# 3     21
# 4     18
# 5     18
# 6     14
# 7     24
# 8     22
# 9     19
# 10    17
# 11    16
# 12    17
# 13    15
# 14    10
# 15    10
# 16    14
# 17    32
# 18    30
# 19    33
# 20    21
# 21    15
# 22    15
# 23    13
# 24    19
# 25    27
# 26    26
# 27    30
# 28    15
# 29    19
# 30    15
# 31    21
# Name: mpg, dtype: int32

# %%
df.drop(['drat'], axis =1, inplace = True)

# %%
df.head(1)
# Out:
#    S.No Unnamed: 1   mpg  cyl   disp   hp    wt   qsec  vs  am  gear  carb
# 0     1  Mazda RX4  21.0    6  160.0  110  2.62  16.46   0   1     4     4

# %%
drop = df.drop(columns = ["S.No"]) # deleting column
drop
# Out:
#              Unnamed: 1  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4   21    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag   21    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710   22    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive   21    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   18    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant   18    6  225.0  105  2.76  3.460    NaN   1   0
# 6            Duster 360   14    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D   24    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230   22    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280   19    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C   17    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE   16    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %% [markdown]
# # Data manipulation

# %% [markdown]
# used to check and replace missing values

# %%
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.describe().T  # all numeric column
# Out:
#       count        mean         std     min        25%      50%     75%  \
# S.No   32.0   16.500000    9.380832   1.000    8.75000   16.500   24.25
# mpg    32.0   20.090625    6.026948  10.400   15.42500   19.200   22.80
# cyl    32.0    6.187500    1.785922   4.000    4.00000    6.000    8.00
# disp   32.0  230.721875  123.938694  71.100  120.82500  196.300  326.00
# hp     32.0  146.687500   68.562868  52.000   96.50000  123.000  180.00
# drat   32.0    3.596562    0.534679   2.760    3.08000    3.695    3.92
# wt     32.0    3.217250    0.978457   1.513    2.58125    3.325    3.61
# qsec   29.0   17.674828    1.780394  14.500   16.87000   17.420   18.60
# vs     32.0    0.437500    0.504016   0.000    0.00000    0.000    1.00
# am     32.0    0.406250    0.498991   0.000    0.00000    0.000    1.00
# gear   32.0    3.687500    0.737804   3.000    3.00000    4.000    4.00
# carb   32.0    2.812500    1.615200   1.000    2.00000    2.000    4.00
#
#           max
# S.No   32.000
# ...

# %%
df.describe(include = object)
# Out:
#        Unnamed: 1
# count          32
# unique         32
# top     Mazda RX4
# freq            1

# %% [raw]
# Replace missing value - with the mean of the column when column dtype = int
#                       - with the mode of the column when column dtype = str

# %%
df.qsec.mean()
# Out:
# 17.6748275862069

# %%
df['qsec'].mean()
# Out:
# 17.6748275862069

# %%
# Replace the missing values 
df.fillna(df.qsec.mean(), inplace = True)

# %%
df.fillna( df.qsec.mean() ).describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596562
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.692055   0.504016   0.498991   0.737804   1.6152
# ...

# %%
df.qsec.fillna( df.qsec.mean() )
# Out:
# 0     16.460000
# 1     17.020000
# 2     18.610000
# 3     19.440000
# 4     17.020000
# 5     17.674828
# 6     15.840000
# 7     20.000000
# 8     22.900000
# 9     18.300000
# 10    18.900000
# 11    17.400000
# 12    17.600000
# 13    18.000000
# 14    17.980000
# 15    17.820000
# 16    17.420000
# 17    17.674828
# 18    18.520000
# 19    19.900000
# 20    20.010000
# 21    16.870000
# 22    17.300000
# 23    15.410000
# 24    17.050000
# 25    17.674828
# 26    16.700000
# 27    16.900000
# 28    14.500000
# 29    15.500000
# 30    14.600000
# 31    18.600000
# Name: qsec, dtype: float64

# %% [markdown]
# # calculate correlation

# %%
df.corr()  # we can display the correlation of different numeric columns
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_29012\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           S.No       mpg       cyl      disp        hp      drat        wt  \
# S.No  1.000000  0.084699 -0.028882 -0.022048  0.242295  0.240952 -0.162419
# mpg   0.084699  1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659
# cyl  -0.028882 -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496
# disp -0.022048 -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980
# hp    0.242295 -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748
# drat  0.240952  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441
# wt   -0.162419 -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000
# qsec -0.362390  0.360351 -0.548775 -0.385207 -0.650674  0.120175 -0.130362
# ...

# %%
## Drop columns of a dataframe 

df.drop(columns = ['vs','am'])
#df.drop('vs','am', axis = 1)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40
# ...

# %% [raw]
# # Index by position (positve and negative index)
# #index by label (location)

# %%
# iloc 
df.iloc[ : , : ]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
# loc 
df.loc[ : , : ]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
# 2 to 8th row of cyl to wt 

df.loc[2:8,'cyl':'wt']
# Out:
#    cyl   disp   hp  drat     wt
# 2    4  108.0   93  3.85  2.320
# 3    6  258.0  110  3.08  3.215
# 4    8  360.0  175  3.15  3.440
# 5    6  225.0  105  2.76  3.460
# 6    8  360.0  245  3.21  3.570
# 7    4  146.7   62  3.69  3.190
# 8    4  140.8   95  3.92  3.150

# %%
df.iloc[2:9,3:8] # index
# Out:
#    cyl   disp   hp  drat     wt
# 2    4  108.0   93  3.85  2.320
# 3    6  258.0  110  3.08  3.215
# 4    8  360.0  175  3.15  3.440
# 5    6  225.0  105  2.76  3.460
# 6    8  360.0  245  3.21  3.570
# 7    4  146.7   62  3.69  3.190
# 8    4  140.8   95  3.92  3.150

# %%
# All rows of cyl column 
df.loc[:,'cyl':'cyl']
# Out:
#     cyl
# 0     6
# 1     6
# 2     4
# 3     6
# 4     8
# 5     6
# 6     8
# 7     4
# 8     4
# 9     6
# 10    6
# 11    8
# 12    8
# 13    8
# 14    8
# 15    8
# 16    8
# 17    4
# 18    4
# 19    4
# 20    4
# 21    8
# 22    8
# 23    8
# 24    8
# 25    4
# 26    4
# 27    4
# 28    8
# 29    6
# 30    8
# 31    4

# %%
# First 5 rows from beginning till mpg including mpg column
df.loc[ :5, :'mpg']
# Out:
#    S.No         Unnamed: 1   mpg
# 0     1          Mazda RX4  21.0
# 1     2      Mazda RX4 Wag  21.0
# 2     3         Datsun 710  22.8
# 3     4     Hornet 4 Drive  21.4
# 4     5  Hornet Sportabout  18.7
# 5     6            Valiant  18.1

# %%
# Access specific rows and specific columns - Pass them as a list 

# 3rd, 4th and 16th row of mpg, cyl and gear column 

df.loc[[3,4,16],['mpg','cyl','gear']]
# Out:
#      mpg  cyl  gear
# 3   21.4    6     3
# 4   18.7    8     3
# 16  14.7    8     3

# %%
df.loc[[5],['mpg']]
# Out:
#     mpg
# 5  18.1

# %%
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl  newcol   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6     100  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6     100  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4     100  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6     100  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8     100  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6     100  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8     100  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4     100  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4     100  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6     100  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6     100  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8     100  275.8  180  3.07  4.070
# ...

# %%
df.vs=11 # or df['vs']=11

# %%
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46  11
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02  11
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61  11
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44  11
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  11
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN  11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84  11
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00  11
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90  11
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30  11
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90  11
# ...

# %%
df.vs == 11    # checking condition
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# Name: vs, dtype: bool

# %%
df['vs'][3]=100
df
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_39760\2625183646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vs'][3]=100
#     S.No           Unnamed: 1   mpg  cyl  newcol   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6     100  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6     100  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4     100  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6     100  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8     100  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6     100  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8     100  360.0  245  3.21  3.570
# ...

# %%
# Create a new column 

df["kmpl"] = 0
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl  newcol   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6     100  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6     100  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4     100  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6     100  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8     100  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6     100  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8     100  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4     100  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4     100  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6     100  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6     100  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8     100  275.8  180  3.07  4.070
# ...

# %%
df['kmpl']=df['mpg']*.42
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl  newcol   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6     100  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6     100  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4     100  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6     100  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8     100  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6     100  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8     100  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4     100  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4     100  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6     100  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6     100  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8     100  275.8  180  3.07  4.070
# ...

# %%
# Create a column in the middle of the data

df.insert(loc = 4, column = 'newcol', value = 100)
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl  newcol   disp   hp  drat     wt  \
# 0      1            Mazda RX4  21.0    6     100  160.0  110  3.90  2.620
# 1      2        Mazda RX4 Wag  21.0    6     100  160.0  110  3.90  2.875
# 2      3           Datsun 710  22.8    4     100  108.0   93  3.85  2.320
# 3      4       Hornet 4 Drive  21.4    6     100  258.0  110  3.08  3.215
# 4      5    Hornet Sportabout  18.7    8     100  360.0  175  3.15  3.440
# 5      6              Valiant  18.1    6     100  225.0  105  2.76  3.460
# 6      7           Duster 360  14.3    8     100  360.0  245  3.21  3.570
# 7      8            Merc 240D  24.4    4     100  146.7   62  3.69  3.190
# 8      9             Merc 230  22.8    4     100  140.8   95  3.92  3.150
# 9     10             Merc 280  19.2    6     100  167.6  123  3.92  3.440
# 10    11            Merc 280C  17.8    6     100  167.6  123  3.92  3.440
# 11    12           Merc 450SE  16.4    8     100  275.8  180  3.07  4.070
# ...

# %%
df = df.drop(columns = ['newcol'])
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   11
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   11
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   11
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44  100
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   11
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   11
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   11
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   11
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   11
# ...

# %%
df.vs[df.vs == 11] == 110
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   11
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   11
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   11
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44  100
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   11
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   11
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   11
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   11
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   11
# ...

# %%
# Sorting : Sorting the values of a column - Default sorting is ascending 
df.sort_values(by = 'mpg')
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   11
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   11
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   11
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   11
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   11
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   11
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   11
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   11
# ...

# %%
df.sort_values('mpg').head(2)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
#
#     am  gear  carb
# 15   0     3     4
# 14   0     3     4

# %%
df.mpg.sort_values()
# Out:
# 15    10.4
# 14    10.4
# 23    13.3
# 6     14.3
# 16    14.7
# 30    15.0
# 13    15.2
# 22    15.2
# 21    15.5
# 28    15.8
# 11    16.4
# 12    17.3
# 10    17.8
# 5     18.1
# 4     18.7
# 9     19.2
# 24    19.2
# 29    19.7
# 0     21.0
# 1     21.0
# 3     21.4
# 31    21.4
# 20    21.5
# 8     22.8
# 2     22.8
# 7     24.4
# 26    26.0
# 25    27.3
# 27    30.4
# 18    30.4
# 17    32.4
# 19    33.9
# Name: mpg, dtype: float64

# %%
df.sort_values(by = 'Unnamed: 1')
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   11
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   11
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   11
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 29    30         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   11
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   11
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   11
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   11
# ...

# %%
df.sort_values(by = 'disp', ascending = False)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   11
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   11
# 24    25     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   11
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   11
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   11
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   11
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   11
# ...

# %%
df.sort_values(by = ['cyl','gear'])
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 20    21        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   11
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   11
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   11
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   11
# 17    18             Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN   11
# 18    19          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   11
# 19    20       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   11
# 25    26            Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN   11
# 31    32           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   11
# 26    27        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   11
# 27    28         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   11
# ...

# %%
df.sort_values(by = ['cyl','gear'], ascending = False)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 28    29       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   11
# 30    31        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   11
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   11
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   11
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   11
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   11
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   11
# ...

# %%
df.sort_values(by = ['cyl','gear'], ascending = [False, True])
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec   vs  \
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   11
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   11
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   11
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   11
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   11
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   11
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   11
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   11
# ...

# %% [raw]
# # Filter - Filter the "True" rows
# in pandas we can filter only true values only

# %%
df.cyl==4
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27     True
# 28    False
# 29    False
# 30    False
# 31     True
# Name: cyl, dtype: bool

# %%
## Filter numerical columns 
df[df.cyl==4]
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 2      3      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61  11   1
# 7      8       Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00  11   0
# 8      9        Merc 230  22.8    4  140.8   95  3.92  3.150  22.90  11   0
# 17    18        Fiat 128  32.4    4   78.7   66  4.08  2.200    NaN  11   1
# 18    19     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52  11   1
# 19    20  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90  11   1
# 20    21   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01  11   0
# 25    26       Fiat X1-9  27.3    4   79.0   66  4.08  1.935    NaN  11   1
# 26    27   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70  11   1
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90  11   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60  11   1
#
#     gear  carb    kmpl
# 2      4     1   9.576
# ...

# %%
df[df['S.No']==22]
# Out:
#     S.No        Unnamed: 1   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  \
# 21    22  Dodge Challenger  15.5    8  318.0  150  2.76  3.52  16.87  11   0
#
#     gear  carb  kmpl
# 21     3     2  6.51

# %%
# Filter categorical columns 
df[df['Unnamed: 1'].str.startswith('Merc')]
# Out:
#     S.No   Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8    Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0  11   0     4
# 8      9     Merc 230  22.8    4  140.8   95  3.92  3.15  22.9  11   0     4
# 9     10     Merc 280  19.2    6  167.6  123  3.92  3.44  18.3  11   0     4
# 10    11    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9  11   0     4
# 11    12   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4  11   0     3
# 12    13   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6  11   0     3
# 13    14  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0  11   0     3
#
#     carb    kmpl
# 7      2  10.248
# 8      2   9.576
# 9      4   8.064
# 10     4   7.476
# 11     3   6.888
# 12     3   7.266
# 13     3   6.384

# %%
df[df['Unnamed: 1'].str.contains('Merc')]
# Out:
#     S.No   Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8    Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0  11   0     4
# 8      9     Merc 230  22.8    4  140.8   95  3.92  3.15  22.9  11   0     4
# 9     10     Merc 280  19.2    6  167.6  123  3.92  3.44  18.3  11   0     4
# 10    11    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9  11   0     4
# 11    12   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4  11   0     3
# 12    13   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6  11   0     3
# 13    14  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0  11   0     3
#
#     carb    kmpl
# 7      2  10.248
# 8      2   9.576
# 9      4   8.064
# 10     4   7.476
# 11     3   6.888
# 12     3   7.266
# 13     3   6.384

# %%
df[df['Unnamed: 1'].str.endswith('D')]
# Out:
#    S.No Unnamed: 1   mpg  cyl   disp  hp  drat    wt  qsec  vs  am  gear  \
# 7     8  Merc 240D  24.4    4  146.7  62  3.69  3.19  20.0  11   0     4
#
#    carb    kmpl
# 7     2  10.248

# %% [markdown]
# # Filter

# %%
df[(df.cyl>6)|(df.gear>4)]
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  11
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84  11
# 11    12           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40  11
# 12    13           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60  11
# 13    14          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00  11
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98  11
# 15    16  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82  11
# 16    17    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42  11
# 21    22     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87  11
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30  11
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41  11
# ...

# %%
df[(df.cyl > 6) & (df.gear > 4)]
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5  11   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6  11   1
#
#     gear  carb   kmpl
# 28     5     4  6.636
# 30     5     8  6.300

# %%
# Filter strings and numbers - String contains "Merc" and Gear == 4
df[(df['Unnamed: 1'].str.contains('Merc')) & (df['gear']==4)]
# Out:
#     S.No Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 7      8  Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0  11   0     4
# 8      9   Merc 230  22.8    4  140.8   95  3.92  3.15  22.9  11   0     4
# 9     10   Merc 280  19.2    6  167.6  123  3.92  3.44  18.3  11   0     4
# 10    11  Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9  11   0     4
#
#     carb    kmpl
# 7      2  10.248
# 8      2   9.576
# 9      4   8.064
# 10     4   7.476

# %%
# sting contains 'P' and mpg greater than 20
df[(df['Unnamed: 1'].str.contains('P')) &(df['mpg']>20)]
# Out:
#     S.No     Unnamed: 1   mpg  cyl   disp  hp  drat    wt  qsec  vs  am  gear  \
# 26    27  Porsche 914-2  26.0    4  120.3  91  4.43  2.14  16.7  11   1     5
#
#     carb   kmpl
# 26     2  10.92

# %%
#we can give more than 1 filter seperatly 
df[(df['Unnamed: 1'].str.contains('Merc')) & (df['gear']==4)][(df['Unnamed: 1'].str.contains('Merc')) &(df['mpg']>20)]
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_29012\1721005830.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df['Unnamed: 1'].str.contains('Merc')) & (df['gear']==4)][(df['Unnamed: 1'].str.contains('Merc')) &(df['mpg']>20)]
#    S.No Unnamed: 1   mpg  cyl   disp  hp  drat    wt  qsec  vs  am  gear  carb
# 7     8  Merc 240D  24.4    4  146.7  62  3.69  3.19  20.0   1   0     4     2
# 8     9   Merc 230  22.8    4  140.8  95  3.92  3.15  22.9   1   0     4     2

# %%
df['carb'].value_counts()
# Out:
# 4    10
# 2    10
# 1     7
# 3     3
# 6     1
# 8     1
# Name: carb, dtype: int64

# %%
df['carb'].value_counts().values
# Out:
# array([10, 10,  7,  3,  1,  1], dtype=int64)

# %%
df[df['carb']==3]
# Out:
#     S.No   Unnamed: 1   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 11    12   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   0   0     3
# 12    13   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   0   0     3
# 13    14  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   0   0     3
#
#     carb
# 11     3
# 12     3
# 13     3

# %%
df.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %% [markdown]
# ### Applying Functions

# %%
# using lambda function
f = lambda x :x*2
car = df.gear.apply(f)  # for one column
car
# Out:
# 0      8
# 1      8
# 2      8
# 3      6
# 4      6
# 5      6
# 6      6
# 7      8
# 8      8
# 9      8
# 10     8
# 11     6
# 12     6
# 13     6
# 14     6
# 15     6
# 16     6
# 17     8
# 18     8
# 19     8
# 20     6
# 21     6
# 22     6
# 23     6
# 24     6
# 25     8
# 26    10
# 27    10
# 28    10
# 29    10
# 30    10
# 31     8
# Name: gear, dtype: int64

# %%
f = lambda x :x*2 # for table
car = df.apply(f)
car
# Out:
#     S.No                              Unnamed: 1  mpg  cyl   disp   hp  drat  \
# 0      2                      Mazda RX4Mazda RX4   42   12  320.0  220  7.80
# 1      4              Mazda RX4 WagMazda RX4 Wag   42   12  320.0  220  7.80
# 2      6                    Datsun 710Datsun 710   44    8  216.0  186  7.70
# 3      8            Hornet 4 DriveHornet 4 Drive   42   12  516.0  220  6.16
# 4     10      Hornet SportaboutHornet Sportabout   36   16  720.0  350  6.30
# 5     12                          ValiantValiant   36   12  450.0  210  5.52
# 6     14                    Duster 360Duster 360   28   16  720.0  490  6.42
# 7     16                      Merc 240DMerc 240D   48    8  293.4  124  7.38
# 8     18                        Merc 230Merc 230   44    8  281.6  190  7.84
# 9     20                        Merc 280Merc 280   38   12  335.2  246  7.84
# 10    22                      Merc 280CMerc 280C   34   12  335.2  246  7.84
# ...

# %%
def gear(x):
    if x== 3:
        print('auto')
    elif x == 4:
        print('car')
    else:
        print('super car')
gear()
# Out:
# car

# %%
aa=df.gear.apply(gear)
# Out:
# car
# car
# car
# auto
# auto
# auto
# auto
# car
# car
# car
# car
# auto
# auto
# auto
# auto
# auto
# auto
# car
# car
# car
# auto
# auto
# auto
# auto
# auto
# car
# super car
# super car
# super car
# super car
# super car
# car

# %%
df.gear.value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %% [markdown]
# ## Pandas Groupby and Aggregate Functions

# %% [markdown]
# groupby used Summarizing or grouping data

# %%
import pandas as pd
df = pd.read_csv('Sample_-_Superstore.csv')
df.head()
# Out:
#           Category             City        Country    Customer Name  Discount  \
# 0        Furniture        Henderson  United States      Claire Gute      0.00
# 1        Furniture        Henderson  United States      Claire Gute      0.00
# 2  Office Supplies      Los Angeles  United States  Darrin Van Huff      0.00
# 3        Furniture  Fort Lauderdale  United States   Sean O'Donnell      0.45
# 4  Office Supplies  Fort Lauderdale  United States   Sean O'Donnell      0.20
#
#    Number of Records  Order Date        Order ID  Postal Code Manufacturer  \
# 0                  1   11/8/2017  CA-2017-152156      42420.0         Bush
# 1                  1   11/8/2017  CA-2017-152156      42420.0          Hon
# 2                  1   6/12/2017  CA-2017-138688      90036.0    Universal
# 3                  1  10/11/2016  US-2016-108966      33311.0     Bretford
# 4                  1  10/11/2016  US-2016-108966      33311.0        Eldon
#
# ...

# %%
df.head(2).T
# Out:
#                                                    0  \
# Category                                   Furniture
# City                                       Henderson
# Country                                United States
# Customer Name                            Claire Gute
# Discount                                         0.0
# Number of Records                                  1
# Order Date                                 11/8/2017
# Order ID                              CA-2017-152156
# Postal Code                                  42420.0
# Manufacturer                                    Bush
# Product Name       Bush Somerset Collection Bookcase
# Profit                                       41.9136
# Quantity                                           2
# Region                                         South
# Sales                                         261.96
# Segment                                     Consumer
# Ship Date                                 11/11/2017
# ...

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer Name', 'Discount',
#        'Number of Records', 'Order Date', 'Order ID', 'Postal Code',
#        'Manufacturer', 'Product Name', 'Profit', 'Quantity', 'Region', 'Sales',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category'],
#       dtype='object')

# %%
df.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df.Category.nunique()
# Out:
# 3

# %%
df['Order Date'] = df['Order Date'].astype('datetime64')

# %%
df['Postal Code'] = df['Postal Code'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           9994 non-null   object
#  1   City               9994 non-null   object
#  2   Country            9994 non-null   object
#  3   Customer Name      9994 non-null   object
#  4   Discount           9994 non-null   float64
#  5   Number of Records  9994 non-null   int64
#  6   Order Date         9994 non-null   datetime64[ns]
#  7   Order ID           9994 non-null   object
#  8   Postal Code        9994 non-null   object
#  9   Manufacturer       9994 non-null   object
#  10  Product Name       9994 non-null   object
#  11  Profit             9994 non-null   float64
#  12  Quantity           9994 non-null   int64
#  13  Region             9994 non-null   object
#  14  Sales              9994 non-null   float64
# ...

# %%
df.groupby('Category')['Sales'].sum()#single aggregation - sum
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Sales'].sum().reset_index()
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
df[['Sales']].groupby(df['Category']).sum()
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
df.groupby('Sub-Category')['Profit'].sum().reset_index()
# Out:
#    Sub-Category      Profit
# 0   Accessories  41936.6357
# 1    Appliances  18138.0054
# 2           Art   6527.7870
# 3       Binders  30221.7633
# 4     Bookcases  -3472.5560
# 5        Chairs  26590.1663
# 6       Copiers  55617.8249
# 7     Envelopes   6964.1767
# 8     Fasteners    949.5182
# 9   Furnishings  13059.1436
# 10       Labels   5546.2540
# 11     Machines   3384.7569
# 12        Paper  34053.5693
# 13       Phones  44515.7306
# 14      Storage  21278.8264
# 15     Supplies  -1189.0995
# 16       Tables -17725.4811

# %%
df.groupby('Category')['Sales'].mean().reset_index()
# Out:
#           Category       Sales
# 0        Furniture  349.834887
# 1  Office Supplies  119.324101
# 2       Technology  452.709276

# %%
df.groupby('Category')['Profit'].sum().reset_index()
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
df.groupby('Category')[['Sales','Profit']].sum().reset_index()
# Out:
#           Category        Sales       Profit
# 0        Furniture  741999.7953   18451.2728
# 1  Office Supplies  719047.0320  122490.8008
# 2       Technology  836154.0330  145454.9481

# %% [markdown]
# ### Multiple Aggregation

# %% [markdown]
# ### Multiple `named` Aggregation
# `most widely used`

# %%
df.groupby(['Category', 'Sub-Category']).agg(
Total_Sales = ('Sales', 'sum'),
Total_Profit = ('Profit', 'sum'),
Avg_Sales = ('Sales', 'mean'),  
Avg_Profit = ('Profit', 'mean'),
Distinct_Product = ('Product Name', 'nunique'),
Total_Count = ('Product Name', 'count')
).reset_index()
# Out:
#            Category Sub-Category  Total_Sales  Total_Profit    Avg_Sales  \
# 0         Furniture    Bookcases  114879.9963    -3472.5560   503.859633
# 1         Furniture       Chairs  328449.1030    26590.1663   532.332420
# 2         Furniture  Furnishings   91705.1640    13059.1436    95.825668
# 3         Furniture       Tables  206965.5320   -17725.4811   648.794771
# 4   Office Supplies   Appliances  107532.1610    18138.0054   230.755710
# 5   Office Supplies          Art   27118.7920     6527.7870    34.068834
# 6   Office Supplies      Binders  203412.7330    30221.7633   133.560560
# 7   Office Supplies    Envelopes   16476.4020     6964.1767    64.867724
# 8   Office Supplies    Fasteners    3024.2800      949.5182    13.936774
# 9   Office Supplies       Labels   12486.3120     5546.2540    34.303055
# 10  Office Supplies        Paper   78479.2060    34053.5693    57.284092
# 11  Office Supplies      Storage  223843.6080    21278.8264   264.590553
# ...

# %%
df.groupby(['Category','Sub-Category'])['Sales'].sum().reset_index()
# Out:
#            Category Sub-Category        Sales
# 0         Furniture    Bookcases  114879.9963
# 1         Furniture       Chairs  328449.1030
# 2         Furniture  Furnishings   91705.1640
# 3         Furniture       Tables  206965.5320
# 4   Office Supplies   Appliances  107532.1610
# 5   Office Supplies          Art   27118.7920
# 6   Office Supplies      Binders  203412.7330
# 7   Office Supplies    Envelopes   16476.4020
# 8   Office Supplies    Fasteners    3024.2800
# 9   Office Supplies       Labels   12486.3120
# 10  Office Supplies        Paper   78479.2060
# 11  Office Supplies      Storage  223843.6080
# 12  Office Supplies     Supplies   46673.5380
# 13       Technology  Accessories  167380.3180
# 14       Technology      Copiers  149528.0300
# 15       Technology     Machines  189238.6310
# 16       Technology       Phones  330007.0540

# %%
df.groupby(['Region']).agg(total_quantity = ('Quantity','sum'),
                        Total_Profit = ('Profit','sum'),
                         Avg_Sales = ('Sales','mean'),
                        Distinct_product = ('Product Name','nunique')).reset_index()
# Out:
#     Region  total_quantity  Total_Profit   Avg_Sales  Distinct_product
# 0  Central            8780    39706.3625  215.772661              1295
# 1     East           10618    91522.7800  238.336110              1415
# 2    South            6209    46749.4303  241.803645              1042
# 3     West           12266   108418.4489  226.493233              1503

# %%
df.groupby('Region').agg(
    Total_Quantity = ('Quantity', 'sum'),
     Total_Profit = ('Profit', 'sum'),
     Average_Sales = ('Sales', 'mean'),
     Average_Profit = ('Profit', 'mean'),
    Distinct_Product = ('Product Name','nunique'),
    Total_count = ('Product Name','count')
).reset_index()
# Out:
#     Region  Total_Quantity  Total_Profit  Average_Sales  Average_Profit  \
# 0  Central            8780    39706.3625     215.772661       17.092709
# 1     East           10618    91522.7800     238.336110       32.135808
# 2    South            6209    46749.4303     241.803645       28.857673
# 3     West           12266   108418.4489     226.493233       33.849032
#
#    Distinct_Product  Total_count
# 0              1295         2323
# 1              1415         2848
# 2              1042         1620
# 3              1503         3203

# %%
df1 = df.groupby(['Region','Category']).agg(total_sales = ('Sales','sum'),
                                           total_profit = ('Profit','sum')).reset_index()

# %%
df1
# Out:
#      Region         Category  total_sales  total_profit
# 0   Central        Furniture  163797.1638    -2871.0494
# 1   Central  Office Supplies  167026.4150     8879.9799
# 2   Central       Technology  170416.3120    33697.4320
# 3      East        Furniture  208291.2040     3046.1658
# 4      East  Office Supplies  205516.0550    41014.5791
# 5      East       Technology  264973.9810    47462.0351
# 6     South        Furniture  117298.6840     6771.2061
# 7     South  Office Supplies  125651.3130    19986.3928
# 8     South       Technology  148771.9080    19991.8314
# 9      West        Furniture  252612.7435    11504.9503
# 10     West  Office Supplies  220853.2490    52609.8490
# 11     West       Technology  251991.8320    44303.6496

# %%
df1['profit margin'] = df1['total_profit'] / df1['total_sales']*100

# %%
df1
# Out:
#      Region         Category  total_sales  total_profit  profit margin
# 0   Central        Furniture  163797.1638    -2871.0494      -1.752808
# 1   Central  Office Supplies  167026.4150     8879.9799       5.316512
# 2   Central       Technology  170416.3120    33697.4320      19.773595
# 3      East        Furniture  208291.2040     3046.1658       1.462455
# 4      East  Office Supplies  205516.0550    41014.5791      19.956873
# 5      East       Technology  264973.9810    47462.0351      17.911961
# 6     South        Furniture  117298.6840     6771.2061       5.772619
# 7     South  Office Supplies  125651.3130    19986.3928      15.906235
# 8     South       Technology  148771.9080    19991.8314      13.437908
# 9      West        Furniture  252612.7435    11504.9503       4.554382
# 10     West  Office Supplies  220853.2490    52609.8490      23.821180
# 11     West       Technology  251991.8320    44303.6496      17.581383

# %%
df_super_tb_5_sub = df.groupby('Sub-Category').agg(
Total_Sales= ('Sales', 'sum')).reset_index()

# %%
df_super_tb_5_sub
# Out:
#    Sub-Category  Total_Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
df_super_tb_5_sub_sorted = df_super_tb_5_sub.sort_values(by='Total_Sales', ascending=False)

# %%
df_super_tb_5_sub_sorted #highest to lowest sales
# Out:
#    Sub-Category  Total_Sales
# 13       Phones  330007.0540
# 5        Chairs  328449.1030
# 14      Storage  223843.6080
# 16       Tables  206965.5320
# 3       Binders  203412.7330
# 11     Machines  189238.6310
# 0   Accessories  167380.3180
# 6       Copiers  149528.0300
# 4     Bookcases  114879.9963
# 1    Appliances  107532.1610
# 9   Furnishings   91705.1640
# 12        Paper   78479.2060
# 15     Supplies   46673.5380
# 2           Art   27118.7920
# 7     Envelopes   16476.4020
# 10       Labels   12486.3120
# 8     Fasteners    3024.2800

# %%
df_super_tb_5_sub_sorted.head(5)
# Out:
#    Sub-Category  Total_Sales
# 13       Phones   330007.054
# 5        Chairs   328449.103
# 14      Storage   223843.608
# 16       Tables   206965.532
# 3       Binders   203412.733

# %%
df_super_tb_5_sub_sorted.tail(5)
# Out:
#    Sub-Category  Total_Sales
# 15     Supplies    46673.538
# 2           Art    27118.792
# 7     Envelopes    16476.402
# 10       Labels    12486.312
# 8     Fasteners     3024.280

# %% [markdown]
# ### save result in excel

# %%
df_super_tb_5_sub_sorted.to_excel("Bottom_5.xlsx")

# %%
df.head(2).T
# Out:
#                                                    0  \
# Category                                   Furniture
# City                                       Henderson
# Country                                United States
# Customer Name                            Claire Gute
# Discount                                         0.0
# Number of Records                                  1
# Order Date                                 11/8/2017
# Order ID                              CA-2017-152156
# Postal Code                                  42420.0
# Manufacturer                                    Bush
# Product Name       Bush Somerset Collection Bookcase
# Profit                                       41.9136
# Quantity                                           2
# Region                                         South
# Sales                                         261.96
# Segment                                     Consumer
# Ship Date                                 11/11/2017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           9994 non-null   object
#  1   City               9994 non-null   object
#  2   Country            9994 non-null   object
#  3   Customer Name      9994 non-null   object
#  4   Discount           9994 non-null   float64
#  5   Number of Records  9994 non-null   int64
#  6   Order Date         9994 non-null   object
#  7   Order ID           9994 non-null   object
#  8   Postal Code        9983 non-null   float64
#  9   Manufacturer       9994 non-null   object
#  10  Product Name       9994 non-null   object
#  11  Profit             9994 non-null   float64
#  12  Quantity           9994 non-null   int64
#  13  Region             9994 non-null   object
#  14  Sales              9994 non-null   float64
#  15  Segment            9994 non-null   object
# ...

# %%
df['Order Date'].max()
# Out:
# '9/9/2018'

# %%
df['Order Date'].min()
# Out:
# '1/1/2018'

# %% [markdown]
# ### Date Handling
# `Convert the object to date time format`

# %% [markdown]
# `pd.to_datetime()`

# %%
df['Order Data'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           9994 non-null   object
#  1   City               9994 non-null   object
#  2   Country            9994 non-null   object
#  3   Customer Name      9994 non-null   object
#  4   Discount           9994 non-null   float64
#  5   Number of Records  9994 non-null   int64
#  6   Order Date         9994 non-null   object
#  7   Order ID           9994 non-null   object
#  8   Postal Code        9983 non-null   float64
#  9   Manufacturer       9994 non-null   object
#  10  Product Name       9994 non-null   object
#  11  Profit             9994 non-null   float64
#  12  Quantity           9994 non-null   int64
#  13  Region             9994 non-null   object
#  14  Sales              9994 non-null   float64
#  15  Segment            9994 non-null   object
# ...

# %%
df['Order Date'].max()
# Out:
# '9/9/2018'

# %%
df['Order Date'].min()
# Out:
# '1/1/2018'

# %%
filter_date_range = (df['Order Date']>='2018-12-01 00:00:00')

# %%
df[filter_date_range]['Order Date'].unique()
# Out:
# array(['6/12/2017', '6/9/2015', '4/15/2018', '5/13/2015', '8/27/2015',
#        '7/16/2018', '9/25/2016', '9/17/2016', '9/10/2018', '7/17/2017',
#        '9/19/2018', '3/11/2017', '6/20/2017', '4/18/2016', '6/17/2017',
#        '4/30/2016', '6/4/2017', '9/18/2017', '9/14/2018', '4/26/2016',
#        '9/3/2016', '5/28/2018', '4/5/2017', '9/17/2017', '6/17/2018',
#        '9/6/2017', '8/29/2017', '8/25/2015', '3/2/2016', '4/5/2016',
#        '9/20/2015', '9/5/2017', '9/18/2018', '9/7/2016', '3/13/2017',
#        '5/31/2016', '5/28/2016', '3/1/2015', '5/11/2017', '9/8/2015',
#        '8/5/2015', '9/14/2015', '4/21/2018', '8/26/2015', '7/16/2017',
#        '3/21/2015', '7/6/2018', '6/24/2018', '8/3/2015', '6/3/2018',
#        '8/9/2016', '9/13/2015', '4/7/2018', '6/1/2015', '9/11/2017',
#        '6/8/2018', '9/19/2015', '6/6/2017', '6/16/2018', '7/30/2016',
#        '9/16/2018', '9/26/2016', '5/4/2016', '9/12/2017', '9/27/2015',
# ...

# %% [markdown]
# ### Pivoting in Pandas

# %%
pd.crosstab(index = df['Category'], columns = df['Region'], values = df['Sales'], aggfunc = lambda x : x.mean(), margins = True)
# Out:
# Region              Central        East       South        West         All
# Category
# Furniture        340.534644  346.574383  353.309289  357.302325  349.834887
# Office Supplies  117.458801  120.044425  126.282727  116.422377  119.324101
# Technology       405.753124  495.278469  507.753952  420.687533  452.709276
# All              215.772661  238.336110  241.803645  226.493233  229.858001

# %%
dict_line = {
 'year': [2016, 2017, 2018, 2019, 2020, 2021],
 'price': [200, 250, 260, 220, 280, 300]
}
df_line = pd.DataFrame(dict_line)

# %%
# use plot() method on the dataframe
df_line.plot('year', 'price');

# %%
df['Region'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
df['Region'].value_counts().plot(kind = "barh")
# Out:
# <Axes: >

# %%
df['Segment'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Segment'>

# %%
df.plot(y=['Profit'], kind = 'box')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer Name', 'Discount',
#        'Number of Records', 'Order Date', 'Order ID', 'Postal Code',
#        'Manufacturer', 'Product Name', 'Profit', 'Quantity', 'Region', 'Sales',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category'],
#       dtype='object')

# %%
df.plot(y = 'Quantity', kind = 'hist', bins = 3)
# Out:
# <Axes: ylabel='Frequency'>
