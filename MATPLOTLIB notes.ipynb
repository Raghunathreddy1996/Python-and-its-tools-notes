# %% [markdown]
# # MATPLOTLIB NOTES

# %% [markdown]
# https://python-graph-gallery.com/
#
# https://www.storytellingwithdata.com/

# %% [markdown]
# matplotlib gallery website used to refer the code so that we dont need to remeber all code in matplotlib
#
# https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# https://matplotlib.org/stable/index.html

# %% [markdown]
# Seaborn https://seaborn.pydata.org/

# %%
# !pip install matplotlib

# %%
# !pip install --upgrade matplotlib
# Out:
# ...
#                                               0.0/8.0 MB ? eta -:--:--
#                                               0.1/8.0 MB 1.8 MB/s eta 0:00:05
#      -                                        0.3/8.0 MB 3.4 MB/s eta 0:00:03
#      --                                       0.6/8.0 MB 4.0 MB/s eta 0:00:02
#      ---                                      0.7/8.0 MB 3.9 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
#      ----                                     0.8/8.0 MB 3.8 MB/s eta 0:00:02
# ...

# %%
import matplotlib.pyplot as plt

# %%
dir(plt)
# Out:
# ['AbstractContextManager',
#  'Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'AxLine',
#  'Axes',
#  'BackendFilter',
#  'Button',
#  'Circle',
#  'Colormap',
#  'Enum',
#  'ExitStack',
#  'Figure',
#  'FigureBase',
#  'FigureCanvasBase',
#  'FigureManagerBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'TYPE_CHECKING',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_NO_PYPLOT_NOTE',
#  '_REPL_DISPLAYHOOK',
#  '_ReplDisplayHook',
#  '__annotations__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
# ...

# %%
len(dir(plt))
# Out:
# 267

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.0'

# %% [markdown]
# `magic command`

# %% [markdown]
# - %matplotlib notebook will lead to interactive plots embedded within the notebook
# - %matplotlib inline will lead to static images of your plot embedded in the notebook - preferred

# %%
plt.style.use('seaborn-v0_8-darkgrid')

# %%
plt.subplots(figsize = (14,8)) #plot multiple charts within one canvas
# Out:
# (<Figure size 1400x800 with 1 Axes>, <Axes: >)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.subplots(nrows=2, ncols=3, figsize = (14,8)) #plot multiple charts within one canvas
plt.show()

# %% [markdown]
# # line graph

# %%
#linspace :- used to generate number equal space
import numpy as np
aa = np.linspace(0,10,20)
aa
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
len(aa)
# Out:
# 20

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#generate data using linspace
a = np.linspace(0,10,20)
print(a)
#Graph _ space
fig = plt.figure(figsize=(6,2))
ax1 = plt.subplot() # it tell we r using entair plot
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# [ 0.          0.52631579  1.05263158  1.57894737  2.10526316  2.63157895
#   3.15789474  3.68421053  4.21052632  4.73684211  5.26315789  5.78947368
#   6.31578947  6.84210526  7.36842105  7.89473684  8.42105263  8.94736842
#   9.47368421 10.        ]

# %% [raw]
# graph line ( have to put all code in one shell so it works otherwise it wont work and these plot work in top to bottom as from intitial to final figure)

# %%
import numpy as np
import matplotlib.pyplot as plt

#generate data
a= np.linspace(0,10,20)
a

#Graph _ space
fig = plt.figure(figsize = (6,3))
ax1 = plt.subplot()
ax1.plot(a)

# %%
import numpy as np
import matplotlib.pyplot as plt

#generate data
a= np.linspace(0,10,20)
b = np.linspace(10,30,20)

#Graph _ space
fig = plt.figure(figsize=(6,3))
ax1 =plt.subplot()

#Graph line
ax1.plot(a)
ax1.plot(b)

# %% [raw]
# alpha: line thinkness (trasperancy)
# color: color of line
# marker: pointer to  value
# line style : used for differenr style of line
# subplot empty means use of entair graph( use the whole graph)

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(0,10,20)

fig = plt.figure(figsize=(6,4))
ax1 = plt.subplot()

ax1.plot(a, linewidth = 1, linestyle = '--', color = 'g', alpha = 1, marker = "*")

# %%
import numpy as np
import matplotlib.pyplot as plt

a= np.linspace(0,10,20)

fig = plt.figure(figsize = (6,3)) # plot size it will give
ax1 = plt.subplot() 
ax1.plot(a, linewidth = 1, linestyle = '--')

# %%
import numpy as np
import matplotlib.pyplot as plt

a= np.linspace(0,10,20)
b =np.linspace(5,0,20)

fig = plt.figure(figsize=(6,3))
ax1 = plt.subplot()

ax1.plot(a, linewidth = 1, linestyle = "--", color = "b", alpha = 1, marker = '^')
ax1.plot(b, linewidth = .5, linestyle = '-', color = "r", alpha = .5, marker ='*')

ax1.set(title='A Graph')
plt.legend(['a','b'], loc = 'best')
plt.grid(True)
plt.show()

# %%
# Plots compare
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(0,10,20)
b = np.linspace(5,0,20)

fig = plt.figure(figsize=(5,6))

ax1 = plt.subplot(221)
ax2 = plt.subplot(224)

ax1.plot(a,linewidth=1.0,linestyle='-',color='k',alpha = 1,marker ='*')
ax2.plot(b,linewidth=1.0,linestyle='--',color='r',alpha = 0.5,marker ='^')

ax1.set(title='a - Title')
ax2.set(title='b - Title')
# Out:
# [Text(0.5, 1.0, 'b - Title')]

# %% [markdown]
# # Area plot

# %%
# Area plot 
import matplotlib.pyplot as plt

a = range(0,5)
b = [[10,2,35,4,5],[42,5,10,25,20],[2,13,4,51,6]]

print(a)
print(b)

fig = plt.figure(figsize=(10,5))
ax1 = plt.subplot()

ax1.stackplot(a,b)

plt.title("Area Plot")
plt.xlabel('a - X label')
plt.ylabel('b - y label')

plt.xticks(rotation=45) #rotate x-axis labels

#plt.savefig('Areaplot.png') #it will save the plot at file location
#plt.show()
# Out:
# range(0, 5)
# [[10, 2, 35, 4, 5], [42, 5, 10, 25, 20], [2, 13, 4, 51, 6]]
# (array([-0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5]),
#  [Text(-0.5, 0, '−0.5'),
#   Text(0.0, 0, '0.0'),
#   Text(0.5, 0, '0.5'),
#   Text(1.0, 0, '1.0'),
#   Text(1.5, 0, '1.5'),
#   Text(2.0, 0, '2.0'),
#   Text(2.5, 0, '2.5'),
#   Text(3.0, 0, '3.0'),
#   Text(3.5, 0, '3.5'),
#   Text(4.0, 0, '4.0'),
#   Text(4.5, 0, '4.5')])

# %%
plt.savefig('Areaplot.png')
plt.show()

# %% [markdown]
# Bar plot : hese used to represent catogorical data

# %%
import matplotlib.pyplot as plt

data = {'apple':10,'orange':15,'lime':20}
names = data.keys()
values = data.values()

fig = plt.figure(figsize=(4,2))
ax1 = plt.subplot()

ax1.bar(names, values)
ax1.set(title ="Bar chart")
ax1.set(xlabel = "name")
ax1.set(ylabel = 'values')

plt.xticks(rotation=45) #rotate x-axis labels
# Out:
# ([0, 1, 2], [Text(0, 0, 'apple'), Text(1, 0, 'orange'), Text(2, 0, 'lime')])

# %%
import matplotlib.pyplot as plt

data = {'apple':10, 'orange':15, 'lime':20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (4,2))
ax1 = plt.subplot()

ax1.bar(names, values)

plt.title('Bar plot')
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %%
import matplotlib.pyplot as plt

data = {'apple':10, 'orange':15, 'lime':20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (4,2))
ax1 = plt.subplot()

ax1.bar(names, values, color = 'g', alpha = 0.5)

plt.title('Bar plot')

plt.xlabel('names')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
## bar plot
import matplotlib.pyplot as plt

data ={'apple':10,'orange':15,'lemon':5,'lime':20}
names=list(data.keys())
values=list(data.values())

fig=plt.figure(figsize=(10,5))
ax1=plt.subplot(221)
ax2=plt.subplot(222)
x=ax1.bar(names,values, color='tomato',tick_label=values)

ax2.bar(names,values, color='teal')
plt.title('Bar Plot')
plt.ylabel('Name')
plt.xlabel('Values')
ax1.bar_label(x, padding=10)
#plt.show()
# Out:
# [Text(0, 10, '10'), Text(0, 10, '15'), Text(0, 10, '5'), Text(0, 10, '20')]

# %%
data ={'apple':10,'orange':15,'lemon':5,'lime':20}
names=list(data.keys())
values=list(data.values())

fig=plt.figure(figsize=(10,5))
ax2=plt.subplot(221)

ax2.bar(names,values, color='teal')
plt.title('Bar Plot')
plt.ylabel('Name')
plt.xlabel('Values')
# Out:
# Text(0.5, 0, 'Values')

# %% [markdown]
# # Horizontal Bar graph

# %%
import matplotlib.pyplot as plt

data = {'apple':10, 'orange':15, 'lime':20}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (4,2))
ax1 = plt.subplot()

ax1.barh(names, values, color = 'r', alpha = .5)
        

plt.title('Horizontal bar plot')

plt.xlabel('values')
plt.ylabel('names')
# Out:
# Text(0, 0.5, 'names')

# %% [raw]
# Scatter plot : used for both contineous and discreate

# %%
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize = (6,3))
ax = plt.subplot()

ax.scatter(a,x)

# %%
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize = (6,3))
ax = plt.subplot()

ax.scatter(a,x)

plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize = (6,3))
ax = plt.subplot()                                  #c = color
                                                    #s = size of style  
ax.scatter(a,x, c = "r", s = 180, marker = '^', alpha = 0.9)

# %%
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize = (5,4))
ax1 = plt.subplot()

ax1.scatter(a,x, c = 'b', s = 100, marker = '^', alpha = 0.5)

ax1.scatter(a,y, c = 'r', s =100, marker = '*', alpha = 1)

# %%
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize = (5,4))
ax1 = plt.subplot()

ax1.scatter(a,x, c = 'b', s = 100, marker = '^', alpha = 0.5)
ax1.scatter(a,y, c = 'r', s =100, marker = '*', alpha = 1)

plt.grid(True) # plt.grid()
plt.title('scatter graph')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# Scatter plot 
import matplotlib.pyplot as plt

a = [10,20,30,40,50,60,70,80]
x = [5,2,4,2,1,4,5,2]
y = [1,2,3,4,3,2,1,2]

fig = plt.figure(figsize=(5,4))

ax1 = plt.subplot()

ax1.scatter(a,x,c='y',s=170,edgecolor='k',marker='o',alpha=0.9)
ax1.scatter(a,y,c='r',s=140,edgecolor='g',marker='^',alpha=1)

plt.title('Scatter plot')
plt.grid(True)

#plt.savefig('scatter.png')
#plt.show()

# %% [raw]
# plt.subplots(figsize=(14,6))
#
# ### Show relationship between sales and profit => Scatter Plot
# plt.scatter(df['Sales'], df['Profit'], color='green', s=100)
# plt.title('Relationship between Sales & Profit')
# plt.xlabel('Sales')
# plt.ylabel('Profit')
# plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt

number = [12,23,34,45,56,67,78,89,123,23,4,25,64,85,1,2,3,47,68,55]

fig = plt.figure(figsize = (4,2))
ax1 = plt.subplot()

ax1.hist(number)
# Out:
# (array([5., 3., 1., 2., 2., 3., 2., 1., 0., 1.]),
#  array([  1. ,  13.2,  25.4,  37.6,  49.8,  62. ,  74.2,  86.4,  98.6,
#         110.8, 123. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt

number = [12,23,34,45,56,67,78,89,123,23,4,25,64,85,1,2,3,47,68,55]

fig = plt.figure(figsize = (4,2))
ax1 = plt.subplot()

ax1.hist(number, bins = 7,color='darkred', linestyle='dashed', linewidth=2)
# Out:
# (array([5., 4., 2., 5., 2., 1., 1.]),
#  array([  1.        ,  18.42857143,  35.85714286,  53.28571429,
#          70.71428571,  88.14285714, 105.57142857, 123.        ]),
#  <BarContainer object of 7 artists>)

# %% [raw]
# Bins : making a groups of same number and that form bar with size of same number
# -in histogram bars called bins
# -by changing value of bins we can change number of bars in histogram

# %%
## Histogram 
import matplotlib.pyplot as plt

number = [12,32,43,65,4,23,54,76,87,98,89,87,450,123,234,34,234,45,56,578,564,897,345]

fig = plt.figure(figsize=(4,2))
ax1 = plt.subplot()

ax1.hist(number, bins=5)
plt.show()

# %%
import pandas as pd

total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

df = pd.DataFrame(total)
df.describe()
# Out:
#                0
# count  10.000000
# mean   21.500000
# std    19.704765
# min     1.000000
# 25%    10.000000
# 50%    20.000000
# 75%    27.500000
# max    70.000000

# %% [markdown]
#  **Box plot** :  - it is used to understand the distrubution of data
#  - to define outlier of data

# %%
total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (3,3))
ax1 = plt.subplot()

ax1.boxplot(total)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ae2013450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ae20206d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ae2012cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ae2021850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ae20220d0>],
#  'means': []}

# %%
data
# Out:
# [[20, 4, 1, 30, 20, 10, 20, 70, 30, 10],
#  [10, 30, 1, 45, 17, 2, 30, 44, 2, 8],
#  [30, 20, 10, 5, 20, 10, 60, 20, 40]]

# %%
# Box plot

total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (3,3))
ax1 = plt.subplot()

ax1.boxplot(total)

plt.show() # it used to avoid the print of other data

# %%
total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (4,3))
ax1 = plt.subplot()

ax1.boxplot(data, showmeans = True) # show mean used to show point of mean value

plt.show()

# %%
total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (3,3))
ax1 = plt.subplot()

ax1.boxplot(data, showmeans = True)

plt.grid(True)
plt.title('Box plot')
plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# # Violin plot

# %%
#violin plot

total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (3,3))
ax1 = plt.subplot()

ax1.violinplot(data, showmeans = True)

plt.grid(True)
plt.title('violin plot')

plt.show()

# %%
#violin plot

total = [20,4,1,30,20,10,20,70,30,10]
orders = [10,30,1,45,17,2,30,44,2,8]
discount = [30,20,10,5,20,10,60,20,40]

data = list([total,orders,discount])

fig = plt.figure(figsize = (6,3))
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)
ax1.violinplot(data, showmeans = True, showmedians = False)
ax2.violinplot(data, showmedians = True, showmeans = False)
ax1.grid(True)
ax2.grid(True)
ax1.set_title('violin plot')
ax2.set_title('violin plot')
plt.show()

# %%
# !pip install pillow

# %%
# !pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
import PIL

# %%
dir(PIL)
# Out:
# ['BmpImagePlugin',
#  'ExifTags',
#  'GifImagePlugin',
#  'GimpGradientFile',
#  'GimpPaletteFile',
#  'Image',
#  'ImageChops',
#  'ImageColor',
#  'ImageFile',
#  'ImageMode',
#  'ImageOps',
#  'ImagePalette',
#  'ImageSequence',
#  'JpegImagePlugin',
#  'JpegPresets',
#  'PaletteFile',
#  'PngImagePlugin',
#  'PpmImagePlugin',
#  'TiffImagePlugin',
#  'TiffTags',
#  'UnidentifiedImageError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_binary',
#  '_deprecate',
#  '_imaging',
#  '_plugins',
#  '_util']

# %%
## Image plot 
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt 

img = Image.open('Areaplot.png')
arr = np.array(img)

print(arr[2])
print(arr.ndim)

fig = plt.figure(figsize=(6,8))
ax1 = plt.subplot()

ax1.imshow(arr)
# Out:
# [[255 255 255 255]
#  [255 255 255 255]
#  [255 255 255 255]
#  ...
#  [255 255 255 255]
#  [255 255 255 255]
#  [255 255 255 255]]
# 3

# %%
arr.size
# Out:
# 1228800

# %%
arr.dtype
# Out:
# dtype('uint8')

# %% [raw]
# Pie chart : here we use categorical data

# %%
import matplotlib.pyplot as plt

lab = ['frogs','hogs','dogs','logs']
sizes = [15,30,45,100]
exp = (0,0,0,0)

fig = plt.figure(figsize = (5,7))
ax1 = plt.subplot()

ax1.pie(sizes)

plt.show()

# %%
import matplotlib.pyplot as plt

lab = ['frogs','hogs','dogs','logs']
sizes = [15,30,45,100]
exp = (0,0,0,0)

fig = plt.figure(figsize = (5,7))
ax1 = plt.subplot()

ax1.pie(sizes, labels =lab, autopct = '%0.2f%%', shadow = True, explode = exp)

plt.title('Pie chart')
plt.show()

# %% [markdown]
# autopct means auto percentage and 0.2 means number of decimal in percentage
#
# shadow means black boreder arround pie
#
# explode : it avaoid pie chat

# %%
import matplotlib.pyplot as plt

lab = ['frogs','hogs','dogs','logs']
sizes = [15,30,45,100]
exp = (0,0,0,0)

fig = plt.figure(figsize = (5,5))
ax1 = plt.subplot()

ax1.pie(sizes, labels = lab, shadow = True, explode = exp,startangle=90)

plt.title('pie chart')
plt.show()

# %% [markdown]
# to highlighr perticlar label the we have give value in explode

# %%
import matplotlib.pyplot as plt

lab = ['frogs','hogs','dogs','logs']
sizes = [15,30,45,100]
exp = (0.1,0,0.2,0)

fig = plt.figure(figsize = (5,5))
ax1 = plt.subplot()

ax1.pie(sizes, labels = lab, autopct = '%0.2f%%',shadow = True, explode = exp)

plt.title('pie chart')
plt.show()

# %% [markdown]
# # Sub-Plot

# %%
import numpy as np
import matplotlib.pyplot as plt 

a = np.linspace(0,10,20)
b = np.linspace(5,0,20)

fig = plt.figure(figsize = (5,6)) 

ax1 = plt.subplot(221)
ax2 = plt.subplot(224)

ax1.plot(a)
ax2.plot(b)

ax1.set(xlabel = "x")
ax1.set(ylabel = "Y")
# Out:
# [Text(0, 0.5, 'Y')]

# %% [markdown]
# 221,222,223,224 subplot is divivding same graph in 4 part and selcting one for them  to where we want to put our graph

# %%
import numpy as np
import matplotlib.pyplot as plt 

a = np.linspace(0,10,20)
b = np.linspace(5,0,20)

fig = plt.figure(figsize = (5,6)) 

ax1 = plt.subplot(221)
ax2 = plt.subplot(223)

ax1.plot(a)
ax2.plot(b)

# %%
import numpy as np
import matplotlib.pyplot as plt 

a = np.linspace(0,10,20)
b = np.linspace(5,0,20)

fig = plt.figure(figsize = (5,6)) 

ax1 = plt.subplot(221)
ax2 = plt.subplot(222)

ax1.plot(a)
ax2.plot(b)

# %%
import numpy as np
import matplotlib.pyplot as plt 

a = np.linspace(0,10,20)
b = np.linspace(5,0,20)

fig = plt.figure(figsize = (5,6)) 

ax1 = plt.subplot(231)
ax2 = plt.subplot(236)

ax1.plot(a)
ax2.plot(b)

# %% [markdown]
# # SEABORN

# %% [markdown]
# Seaborn and matplotlib are function same and any one tool is used for graphing and we are using matplotlib

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_oldcore',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
# ...

# %%
len(dir(sns))
# Out:
# 100

# %%
sns.__version__
# Out:
# '0.12.2'

# %% [markdown]
# ### Heatmap

# %%
aa = pd.DataFrame(np.random.random((5,5)), columns=['a','b','c','d','e'])
aa
# Out:
#           a         b         c         d         e
# 0  0.454870  0.857545  0.779905  0.160391  0.740398
# 1  0.150040  0.145220  0.722740  0.983321  0.245533
# 2  0.006792  0.519396  0.913960  0.844655  0.075538
# 3  0.989954  0.209146  0.219997  0.983122  0.089648
# 4  0.228940  0.579157  0.322685  0.140812  0.222399

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(aa, annot = True, cmap = 'BuPu')
plt.show()

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(aa, annot=True, cmap='YlGnBu')
plt.show()

# %%
sns.histplot([1,2,2,3,3,3,4,4,5], bins=3, kde= True)
plt.show()
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns

sns.set_theme(style = 'darkgrid')

#Load an exaple a dataset
fmri =sns.load_dataset('fmri')

#plot
sns.lineplot(x = 'timepoint', y = 'signal', data = fmri)
#plt.show()
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",hue="region", data=fmri)
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal", style="event", data=fmri)
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# hue : is used whem we want to compare the two colomns
#
#   box plot only used to show the out layer in the data
#
# index become column when we covert them in to data frame

# %% [markdown]
# # Reading the external data and plotting graph

# %%
import pandas as pd

df = pd.read_csv("F:/course pdf/3.Pandas/class/mtcars2.csv")
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
import matplotlib.pyplot as plt

a = df['wt']

fig = plt.figure(figsize = (5,3))
ax = plt.subplot()

ax.plot(a)

# %%
import matplotlib.pyplot as plt

#a= df['mpg']

fig = plt.figure(figsize = (6,4))
ax1 = plt.subplot()

ax1.plot(df['mpg'])

# %%
y1= df['hp']
y2 = df['disp']
x = range(32)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(x)

# %% [markdown]
# # Areaplot

# %%
y1= df['hp']
y2 = df['disp']
x = range(32)
plt.stackplot(x,y1, colors = 'blue', alpha = .7)
plt.stackplot(x,y2, colors = 'black', alpha = .5)

# %%
y1= df['hp']
y2 = df['disp']
x = range(32)
plt.plot(x,y1, linewidth = 2, color = 'c')
plt.stackplot(x,y1, colors = 'blue', alpha = .7)
plt.plot(x,y2, linewidth = 1, color = 'r')
plt.stackplot(x,y2, colors = 'black', alpha = .5)

# %%
import matplotlib.pyplot as plt

a= df['mpg']

fig = plt.figure(figsize = (7,5))
ax1 = plt.subplot()

ax1.hist(a) # default bins = 10
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (7,4))
ax1 = plt.subplot()

ax1.plot(df.wt)
plt.show()

# %%
import matplotlib.pyplot as plt
a = df['mpg']

fig = plt.figure(figsize = (7,3))
ax = plt.subplot()

ax.hist(a, bins = 7)
plt.title('Histogram of MPG')
plt.xlabel('bins')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
import matplotlib.pyplot as plt

a= df['gear']
b = df['S.No']

fig = plt.figure(figsize = (4,5))
ax1 = plt.subplot()

ax1.bar(a,b)
plt.title('Bar plot of gear')
# Out:
# Text(0.5, 1.0, 'Bar plot of gear')

# %%
df['gear'].count()
# Out:
# 32

# %%
df['gear'].value_counts()
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
df['gear'].value_counts().values
# Out:
# array([15, 12,  5], dtype=int64)

# %%
df['gear'].value_counts().index
# Out:
# Index([3, 4, 5], dtype='int64', name='gear')

# %%
import matplotlib.pyplot as plt

a= df['gear'].value_counts().index
b = df['gear'].value_counts().values

fig = plt.figure(figsize = (4,4))
ax1 = plt.subplot()

ax1.bar(a,b)
plt.title('Bar plot of gear')
plt.xlabel('index')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
import seaborn as sns
sns.set_theme(style="white")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.8, palette="muted",
            height=6, data=mpg)

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
#ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Hands On

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("F:/course pdf/4.matplotlib/class/cars_final.csv", skipinitialspace = True)
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %%
df.shape
# Out:
# (261, 8)

# %%
df.describe()
# Out:
#               mpg   cylinders  cubicinches          hp    weightlbs  \
# count  261.000000  261.000000   259.000000  261.000000   258.000000
# mean    23.144828    5.590038   200.918919  106.360153  3009.833333
# std      7.823570    1.733310   109.258305   40.499959   854.039019
# min     10.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     16.900000    4.000000    99.500000   75.000000  2248.000000
# 50%     22.000000    6.000000   156.000000   95.000000  2867.500000
# 75%     28.800000    8.000000   303.000000  138.000000  3670.000000
# max     46.600000    8.000000   455.000000  230.000000  4997.000000
#
#        time-to-60         year
# count  261.000000   261.000000
# mean    15.547893  1976.819923
# std      2.910625     3.637696
# min      8.000000  1971.000000
# 25%     14.000000  1974.000000
# 50%     16.000000  1977.000000
# 75%     17.000000  1980.000000
# max     25.000000  1983.000000

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    0
# hp             0
# weightlbs      0
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
sns.scatterplot(x = 'hp', y = 'mpg', data = df, c ='g')
plt.xlabel('Horse Power')
plt.ylabel('Miles Per Gallon')
plt.title('HP Vs MPG')
# Out:
# Text(0.5, 1.0, 'HP Vs MPG')

# %%
#all the graph on a single plane
fig, ax = plt.subplots(2,2,figsize=(20,20))
#hp vs mpg
plt.subplot(2,2,1)
sns.scatterplot(x = df['hp'], y = df['mpg'], data = df, c = 'green')
plt.xlabel('Horse Power')
plt.ylabel('Miles Per Gallon')
plt.title('HP Vs MPG')
#hp vs time-to-60
plt.subplot(2,2,2)
sns.scatterplot(x = 'hp', y = 'time-to-60', data=df, c = 'purple')
plt.xlabel('Horse Power')
plt.ylabel('time-to-60')
plt.title('HP Vs TIME')
#hp vs weightlbs
plt.subplot(2,2,3)
sns.scatterplot(x = 'hp', y = df['weightlbs'], data=df, c = 'red')
plt.xlabel('Horse Power')
plt.ylabel('weightlns')
plt.title('HP Vs WEIGHTLBS')
#hp vs cylinders
plt.subplot(2,2,4)
sns.scatterplot(x = 'hp', y = 'cylinders', data=df, c = 'yellow')
plt.xlabel('Horse Power')
plt.ylabel('Cylinders')
plt.title('HP Vs CYLINDERS')
# Out:
# Text(0.5, 1.0, 'HP Vs CYLINDERS')

# %% [markdown]
# 5.Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60)
# with respect to each brand.

# %%
fig, axes=plt.subplots(2,2,figsize=(20,10))

#hp-mpg
plt.subplot(2,2,1)
sns.scatterplot(x=df['hp'],y=df['mpg'],hue=df['brand'],data=df)
plt.xlabel("Horsepower")
plt.ylabel("Miles per gallon")
plt.title("HP vs MPG")


#mpg-weightlbs
plt.subplot(2,2,2)
sns.scatterplot(x=df['mpg'],y=df['weightlbs'],hue=df['brand'],data=df)
plt.xlabel("Miles per gallon")
plt.ylabel("weightlbs")
plt.title("Mpg vs weightlbs")
# Out:
# Text(0.5, 1.0, 'Mpg vs weightlbs')

# %% [raw]
# Question 2
# Create bar plots for the following, make sure all the plots appear in the same plane with
# x-labels and y-labels evenly spaced.
# 1.Cylinders and Horsepower, Cylinders and miles per gallon, Cylinders and weight.
# 2.Year and time-to-60, Year and miles per gallon, Year and horsepower.
# 3.Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.
# 4.Create a bar plot that shows the visual representation of hp, mpg, weight and time-to-60 with respect to the years, for each brand.

# %%
data = df

# %%
fig,axes=plt.subplots(3,2,figsize=(20,15))

#cylinders vs hp
plt.subplot(3,2,1)
sns.barplot(x=data["cylinders"],y=data['hp'],data=data,color="red")
plt.title("Cylinders vs Horsepower")
plt.xlabel('Cylinders')
plt.ylabel("HP")


plt.subplot(3,2,2)
sns.barplot(x=data["cylinders"],y=data['mpg'],data=data,color="green")
plt.title("Cylinders vs Miles per gallon")
plt.xlabel('Cylinders')
plt.ylabel("MPG")


plt.subplot(3,2,3)
sns.barplot(x=data["cylinders"],y=data['weightlbs'],data=data,color="purple")
plt.title("Cylinders vs weightlbs")
plt.xlabel('Cylinders')
plt.ylabel("Weightlbs")


plt.subplot(3,2,4)
sns.barplot(x=data["year"],y=data['time-to-60'],data=data,color="orange")
plt.title("Year vs Time-to-60")
plt.xlabel('Year')
plt.ylabel("Time-to-60")


plt.subplot(3,2,5)
sns.barplot(x=data["year"],y=data['mpg'],data=data,color="yellow")
plt.title("Year vs MPG")
plt.xlabel('Year')
plt.ylabel("MPG")

plt.subplot(3,2,6)
sns.barplot(x=data["year"],y=data['hp'],data=data,color="blue")
plt.title("Year vs HP")
plt.xlabel('Year')
plt.ylabel("HP")
# Out:
# Text(0, 0.5, 'HP')

# %%
fig= plt.figure(figsize = (6,4))
axes=plt.subplot()

#cylinders vs hp
sns.barplot(x=data["cylinders"],y=data['hp'],hue=data['brand'],data=data)
plt.title("Cylinders vs Horsepower")
plt.xlabel('Cylinders')
plt.ylabel("HP")
# Out:
# Text(0, 0.5, 'HP')

# %% [raw]
# Create box plots for the following:
# 1.Create box plots for the columns hp, mpg, time-to-60, and weight lbs.
# 2.Create box plots for the columns in the step1 with respect to the number of cylinders and brand respectively.

# %%
x=[1,2,3,4,5,6,7,20]
plt.boxplot(x)
plt.show()

# %%
sns.boxplot(x=data['hp'])
plt.title("horsepower")
plt.show()

# %%
sns.boxplot(data['mpg'])
plt.title('Miles-per-Gallon')
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(20,10))


#hp
plt.subplot(2,2,1)
sns.boxplot(x=data['cylinders'],y=data['hp'],hue=data['brand'],data=data,color='red')
plt.title("Hp vs Cylinders")
plt.xlabel("Horsepower")
plt.ylabel("Cylinders")


plt.subplot(2,2,2)
sns.boxplot(x=data['cylinders'],y=data['mpg'],hue=data['brand'],data=data,color='green')
plt.title("Cylinders vs mpg")
plt.xlabel("Cylinders")
plt.ylabel("Mpg")

plt.subplot(2,2,3)
sns.boxplot(x=data['cylinders'],y=data['time-to-60'],hue=data['brand'],data=data,color='blue')
plt.title("Cylinders vs time-to-60")
plt.xlabel("Cylinders")
plt.ylabel("time-to-60")

plt.subplot(2,2,4)
sns.boxplot(x=data['cylinders'],y=data['weightlbs'],hue=data['brand'],data=data,color='purple')
plt.title("Cylinders vs weightlbs")
plt.xlabel("Cylinders")
plt.ylabel('weightlbs')
plt.show()

# %% [raw]
# 1.Create pair plots for the entire data to study various patterns in the data.
# 2.Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
df=pd.DataFrame({'v1':[1,2],'v2':[3,4]})
df
# Out:
#    v1  v2
# 0   1   3
# 1   2   4

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(data)  #used to check the comaprison between all columns to each other
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(data,hue="brand")
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Abhishek\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [raw]
# Create a heatmap for the entire data to study correlation between each of the columns.

# %%
cor=data.corr()
cor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 cor=data.corr()
#       2 cor
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.heatmap(cor,annot= True)

# %% [raw]
# Create a histogram for the following:
# 1.Each column in the data to understand the distribution of the data.
# 2.Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand.
